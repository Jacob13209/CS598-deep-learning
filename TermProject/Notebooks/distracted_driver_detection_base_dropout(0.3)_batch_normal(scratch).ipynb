# %% [markdown]
# # *Distracted Driver Detection with CNN - Base*
#
# **The objectives of this project are the following:**
# - Implement and train an basic CNN model for distracted driver detection
# - Train a model based on a pre-trained model(VGG-19) via transfer learning
# - Evaluate the performance of both models for their loss and accuracy, including training and validation.
# - Load trained models and use it to run classification on test data that the model never seen before.

# %% [markdown]
# ## Libaries
#
# The main software application being used for this project is *Keras*, including data pre-processing, architecture, model training, training callback functions, and model metrics. *matplotlib* and *seaborn* is also imported for plotting; *os* and *glob* are used for locating and accessing files, etc.

# %%
from keras import layers # layers
from keras import models # models
from keras import optimizers # optimizers for complilation 
from keras import losses # losses 
from keras import metrics # metrics
from keras.utils import plot_model # show the model details in graph

### Callback functions ### 
from keras.callbacks import EarlyStopping  # stop earlier
from keras.callbacks import ReduceLROnPlateau # update the learning rate
from keras.callbacks import ModelCheckpoint # save model,weights

from keras.preprocessing.image import ImageDataGenerator # read images and augumentation
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array
from keras.applications import VGG19
from keras.applications import MobileNet

from PIL import Image
from glob import glob

import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import random

# %%
# check the version of keras
import keras
print(keras.__version__)
# Out:
# 2.4.3

# %%
# do i have a GPU available ??? 
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## Dataset
#
# The dataset was found from *kaggle* at: [https://www.kaggle.com/c/state-farm-distracted-driver-detection/data], which includes labeled driver images; each class is an behavior that was classified, such as, texting, eating, talking on the phone, makeup, reaching behind, etc. It also provides test data that are not labeled, all can be found within same folder.
#
# The 10 classes to predict are:
#
# - c0: safe driving
# - c1: texting - right
# - c2: talking on the phone - right
# - c3: texting - left
# - c4: talking on the phone - left
# - c5: operating the radio
# - c6: drinking
# - c7: reaching behind
# - c8: hair and makeup
# - c9: talking to passenger

# %% [markdown]
# ### Descriptions
#
# The downloaded dataset is a compressed zip package, it includes three part after unzip.
#
# - imgs: driver pictures will be used, and including train and test as sub-folders.
# - driver_imgs_list.csv - csv file that includes the name of driver picturs, subject id(driver), class id(class).
# - sample_submission.csv - sample submission file since this is a kaggle competition. (**I WILL NOT USE THIS FILE**)

# %%
CURR_DIR = os.getcwd()

DATA_DIR = os.path.join(CURR_DIR, "data/state-farm-distracted-driver-detection/")

TRAIN_DIR = os.path.join(DATA_DIR, "imgs/train")  # train dir has sub-classes folders 
TEST_DIR = os.path.join(DATA_DIR, "imgs/test")    # test data folder

DATA_FILE = os.path.join(DATA_DIR, "driver_imgs_list.csv") # train images and according class and driver

# ensure the folder exist for saving the models
MODEL_DIR = os.path.join(CURR_DIR, "saved_models")

# create the model dir if not exist
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# define the class and its according description 

# classes 
classes = {'c0','c1','c2','c3','c4','c5','c6','c7','c8','c9'}

# {folder name}:{description}
class_dict = {'c0': 'Safe driving', 
              'c1': 'Texting - right', 
              'c2': 'Talking on the phone - right', 
              'c3': 'Texting - left', 
              'c4': 'Talking on the phone - left', 
              'c5': 'Operating the radio', 
              'c6': 'Drinking', 
              'c7': 'Reaching behind', 
              'c8': 'Hair and makeup', 
              'c9': 'Talking to passenger'}

# %% [markdown]
# #### Parameters setup
#
# Before data pre-processing, I will define the input shape(target height and width), and number of training epochs, and the batch size that helps to reduce the memory usage when running on less powerful platforms.

# %%
#INPUT_WIDTH = 32
#INPUT_HEIGHT = 32

INPUT_WIDTH = 64
INPUT_HEIGHT = 64

# %%
#EPOCHES = 5
#SIZE = 32

EPOCHES = 50
BATCH_SIZE = 128

# %% [markdown]
# #### Data Pre-Processing
#
# With *Keras*, image data processing has become much easier. Instead of reading subfolers for all files, load pictures and covert to numpy array, *Keras* provides API calls, *flow_from_directory*, which will read data from specified directory and categorize to different classes, load with resizing, etc, with the usage of *ImageDataGenerator*.

# %%
train_datagen = ImageDataGenerator(rescale=1./255,       # Pixel values are 255 maximum
                                   validation_split=0.2) # training/validation split

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                    target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                    classes=None, 
                                                    class_mode='categorical',
                                                    batch_size=BATCH_SIZE, 
                                                    shuffle=True, 
                                                    subset='training')

validation_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                         target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                         classes=None, 
                                                         class_mode='categorical',
                                                         batch_size=BATCH_SIZE, 
                                                         shuffle=True, 
                                                         subset='validation')

test_generator = test_datagen.flow_from_directory(TEST_DIR, 
                                                  target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                  classes=None, 
                                                  class_mode='categorical',
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=False)
# Out:
# Found 17943 images belonging to 10 classes.
# Found 4481 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
# calculate the steps for training and validation
TRAIN_STEPS = train_generator.samples // BATCH_SIZE
VALIDATION_STEPS = validation_generator.samples // BATCH_SIZE

# %% [markdown]
# ## Basic CNN Architeture

# %%
model = models.Sequential()

# filters, stride, input size, chanel 
model.add(layers.Conv2D(32, (5,5), padding='same', input_shape=(INPUT_HEIGHT, INPUT_WIDTH, 3)))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(32) * height * width 

model.add(layers.Conv2D(64, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(64) * height/2 * width/2 

model.add(layers.Conv2D(128, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(128) * height/4 * width/4 

model.add(layers.Flatten())

model.add(layers.Dropout(0.3))

model.add(layers.Dense(256))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.Dense(10))

model.add(layers.BatchNormalization())

model.add(layers.Activation("softmax"))

# %%
# use categorical crossentropy since our data is multi-class classification
#loss_func = losses.CategoricalCrossentropy(from_logits=False, name="categorical_crossentropy")

# outperforms others in practice, RMSprop + Momentum
#opt_func = optimizers.Adam(lr=0.0001)

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

#model.compile(loss=loss_func, 
#              optimizer=opt_func, 
#              metrics=['accuracy'])

# %%
# check the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10)                40
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 2,360,562
# Trainable params: 2,359,582
# Non-trainable params: 980
# _________________________________________________________________

# %%
# plot the model in picture format to visualize how layers are connected with according input/output size
plot_model(model, to_file="basic_cnn_model.png", show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Callback functions
#
# Callback functions are provided by *Keras*, which will be executed during the training of the model and can be used for different purposes; In this project, I will use the following three callback APIS:
# - EarlyStopping: stop the training earlier if the specified metric stopped improving
# - ReduceLROnPlateau: adjust the learning rate when the specified metric stopped improving
# - ModelCheckpoint: save the model weights and model each training epoch

# %%
# define callback functions
# 1: early stopping 
# https://keras.io/api/callbacks/early_stopping/
early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

# 2: reduce the learning rate when a metric has stopped improving 
# https://keras.io/api/callbacks/reduce_lr_on_plateau/
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # monitored metric
    factor=0.2,   # new lr = factor * lr
    patience=2,   # number of epochs 
    min_lr=0.001,  # min lr
    verbose=1
)

# 3: save model or model weights
# https://keras.io/api/callbacks/model_checkpoint/
model_path = MODEL_DIR + '/distracted_driver_detection_base.h5'
model_cp = ModelCheckpoint(
    filepath=model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, model_cp]
#callbacks = []

# %%
history=model.fit(train_generator, 
                  steps_per_epoch = TRAIN_STEPS, 
                  epochs = EPOCHES,
                  verbose = 1,
                  validation_data = validation_generator,
                  validation_steps = VALIDATION_STEPS,
                  callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7457 - accuracy: 0.8690
# Epoch 00001: val_loss improved from inf to 2.38369, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 151s 1s/step - loss: 0.7457 - accuracy: 0.8690 - val_loss: 2.3837 - val_accuracy: 0.1181
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.9907
# Epoch 00002: val_loss improved from 2.38369 to 1.62396, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 158s 1s/step - loss: 0.3091 - accuracy: 0.9907 - val_loss: 1.6240 - val_accuracy: 0.3679
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9962
# Epoch 00003: val_loss improved from 1.62396 to 0.52775, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 148s 1s/step - loss: 0.2137 - accuracy: 0.9962 - val_loss: 0.5278 - val_accuracy: 0.9797
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9979
# Epoch 00004: val_loss improved from 0.52775 to 0.18061, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 140s 997ms/step - loss: 0.1622 - accuracy: 0.9979 - val_loss: 0.1806 - val_accuracy: 0.9960
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9992
# Epoch 00005: val_loss improved from 0.18061 to 0.10697, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 141s 1s/step - loss: 0.1265 - accuracy: 0.9992 - val_loss: 0.1070 - val_accuracy: 0.9973
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9996
# Epoch 00006: val_loss did not improve from 0.10697
# 140/140 [==============================] - 140s 1s/step - loss: 0.0993 - accuracy: 0.9996 - val_loss: 0.3533 - val_accuracy: 0.9924
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0873 - accuracy: 0.9997
# Epoch 00007: val_loss improved from 0.10697 to 0.08240, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 143s 1s/step - loss: 0.0873 - accuracy: 0.9997 - val_loss: 0.0824 - val_accuracy: 0.9973
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0677 - accuracy: 0.9998
# Epoch 00008: val_loss improved from 0.08240 to 0.06983, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 140s 1s/step - loss: 0.0677 - accuracy: 0.9998 - val_loss: 0.0698 - val_accuracy: 0.9975
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9992
# Epoch 00009: val_loss improved from 0.06983 to 0.05621, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 140s 1s/step - loss: 0.0704 - accuracy: 0.9992 - val_loss: 0.0562 - val_accuracy: 0.9971
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9995
# Epoch 00010: val_loss improved from 0.05621 to 0.04556, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 140s 1000ms/step - loss: 0.0544 - accuracy: 0.9995 - val_loss: 0.0456 - val_accuracy: 0.9978
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9999
# Epoch 00011: val_loss did not improve from 0.04556
# 140/140 [==============================] - 139s 996ms/step - loss: 0.0444 - accuracy: 0.9999 - val_loss: 0.0473 - val_accuracy: 0.9980
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0387 - accuracy: 1.0000
# Epoch 00012: val_loss improved from 0.04556 to 0.03314, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 140s 1000ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 0.9980
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9996
# Epoch 00013: val_loss did not improve from 0.03314
# 140/140 [==============================] - 140s 1s/step - loss: 0.0411 - accuracy: 0.9996 - val_loss: 0.0836 - val_accuracy: 0.9949
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9994
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00014: val_loss did not improve from 0.03314
# 140/140 [==============================] - 140s 998ms/step - loss: 0.0363 - accuracy: 0.9994 - val_loss: 0.1386 - val_accuracy: 0.9946
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0517 - accuracy: 0.9981Restoring model weights from the end of the best epoch.
#
# Epoch 00015: val_loss did not improve from 0.03314
# 140/140 [==============================] - 141s 1s/step - loss: 0.0517 - accuracy: 0.9981 - val_loss: 0.0414 - val_accuracy: 0.9962
# Epoch 00015: early stopping

# %% [markdown]
# ## Transfer learning on Pre-Trained Model (VGG-19)
#
# VGG-19 architecture is being used for this experienment.

# %%
conv_base = VGG19(weights="imagenet", 
                  include_top = False, # exclude the top three fully connected layer
                  input_shape = (INPUT_HEIGHT, INPUT_WIDTH, 3), # configure the input shape, default is 224*224*3
                 )

# %%
conv_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = conv_base.output

x = layers.Flatten()(x)

x = layers.Dropout(0.3)(x)

x = layers.Dense(256, activation='relu')(x)

predictions = layers.Dense(10, activation='softmax')(x)

# %%
t_model= models.Model(inputs=conv_base.input, outputs=predictions)

# %%
for layer in conv_base.layers:
    layer.trainable = False

#for layer in t_model.layers[:10]:
#    layer.trainable = False

# %%
#t_model.compile(loss='categorical_crossentropy', 
#                #optimizer='adam', 
#                optimizer=optimizers.Adam(lr=0.0001),
#                metrics=['accuracy'])

t_model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
t_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 20,551,498
# Trainable params: 527,114
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(t_model, to_file="transfered_model_vgg19.png", show_shapes=True, show_layer_names=True)

# %%
t_model_path = MODEL_DIR + '/distracted_driver_detection_vgg19.h5'
model_cp = ModelCheckpoint(
    filepath=t_model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

callbacks = [model_cp, early_stop]

# %%
# reset data generator
train_generator.reset()
validation_generator.reset()

t_history=t_model.fit(train_generator, 
                      steps_per_epoch = TRAIN_STEPS, 
                      epochs = EPOCHES,
                      verbose = 1,
                      validation_data = validation_generator,
                      validation_steps = VALIDATION_STEPS,
                      callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3212 - accuracy: 0.5541
# Epoch 00001: val_loss improved from inf to 0.68708, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 293s 2s/step - loss: 1.3212 - accuracy: 0.5541 - val_loss: 0.6871 - val_accuracy: 0.8158
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6800 - accuracy: 0.7816
# Epoch 00002: val_loss improved from 0.68708 to 0.44914, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 317s 2s/step - loss: 0.6800 - accuracy: 0.7816 - val_loss: 0.4491 - val_accuracy: 0.8882
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 0.5350 - accuracy: 0.8280
# Epoch 00003: val_loss improved from 0.44914 to 0.36420, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 309s 2s/step - loss: 0.5350 - accuracy: 0.8280 - val_loss: 0.3642 - val_accuracy: 0.9060
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.8570
# Epoch 00004: val_loss improved from 0.36420 to 0.30388, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 300s 2s/step - loss: 0.4495 - accuracy: 0.8570 - val_loss: 0.3039 - val_accuracy: 0.9156
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4115 - accuracy: 0.8672
# Epoch 00005: val_loss improved from 0.30388 to 0.25814, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 293s 2s/step - loss: 0.4115 - accuracy: 0.8672 - val_loss: 0.2581 - val_accuracy: 0.9339
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3640 - accuracy: 0.8839
# Epoch 00006: val_loss improved from 0.25814 to 0.23579, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 293s 2s/step - loss: 0.3640 - accuracy: 0.8839 - val_loss: 0.2358 - val_accuracy: 0.9364
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3413 - accuracy: 0.8888
# Epoch 00007: val_loss improved from 0.23579 to 0.20903, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 295s 2s/step - loss: 0.3413 - accuracy: 0.8888 - val_loss: 0.2090 - val_accuracy: 0.9446
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8955
# Epoch 00008: val_loss improved from 0.20903 to 0.19711, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 293s 2s/step - loss: 0.3151 - accuracy: 0.8955 - val_loss: 0.1971 - val_accuracy: 0.9471
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.9074
# Epoch 00009: val_loss did not improve from 0.19711
# 140/140 [==============================] - 293s 2s/step - loss: 0.2902 - accuracy: 0.9074 - val_loss: 0.2005 - val_accuracy: 0.9404
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2665 - accuracy: 0.9151
# Epoch 00010: val_loss improved from 0.19711 to 0.17490, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 295s 2s/step - loss: 0.2665 - accuracy: 0.9151 - val_loss: 0.1749 - val_accuracy: 0.9509
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2439 - accuracy: 0.9227
# Epoch 00011: val_loss improved from 0.17490 to 0.15178, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 295s 2s/step - loss: 0.2439 - accuracy: 0.9227 - val_loss: 0.1518 - val_accuracy: 0.9571
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9239
# Epoch 00012: val_loss improved from 0.15178 to 0.14802, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 295s 2s/step - loss: 0.2347 - accuracy: 0.9239 - val_loss: 0.1480 - val_accuracy: 0.9583
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.9315
# Epoch 00013: val_loss improved from 0.14802 to 0.13935, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 311s 2s/step - loss: 0.2148 - accuracy: 0.9315 - val_loss: 0.1393 - val_accuracy: 0.9614
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9350
# Epoch 00014: val_loss improved from 0.13935 to 0.13621, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 313s 2s/step - loss: 0.1985 - accuracy: 0.9350 - val_loss: 0.1362 - val_accuracy: 0.9598
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9365
# Epoch 00015: val_loss improved from 0.13621 to 0.11946, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 0.1984 - accuracy: 0.9365 - val_loss: 0.1195 - val_accuracy: 0.9688
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9421
# Epoch 00016: val_loss did not improve from 0.11946
# 140/140 [==============================] - 342s 2s/step - loss: 0.1786 - accuracy: 0.9421 - val_loss: 0.1315 - val_accuracy: 0.9600
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1825 - accuracy: 0.9394
# Epoch 00017: val_loss improved from 0.11946 to 0.11888, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 329s 2s/step - loss: 0.1825 - accuracy: 0.9394 - val_loss: 0.1189 - val_accuracy: 0.9670
# Epoch 18/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1617 - accuracy: 0.9485
# Epoch 00018: val_loss improved from 0.11888 to 0.10509, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 328s 2s/step - loss: 0.1617 - accuracy: 0.9485 - val_loss: 0.1051 - val_accuracy: 0.9710
# Epoch 19/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1614 - accuracy: 0.9467
# Epoch 00019: val_loss did not improve from 0.10509
# 140/140 [==============================] - 325s 2s/step - loss: 0.1614 - accuracy: 0.9467 - val_loss: 0.1082 - val_accuracy: 0.9685
# Epoch 20/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1572 - accuracy: 0.9478
# Epoch 00020: val_loss improved from 0.10509 to 0.10123, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 324s 2s/step - loss: 0.1572 - accuracy: 0.9478 - val_loss: 0.1012 - val_accuracy: 0.9683
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9523
# Epoch 00021: val_loss did not improve from 0.10123
# 140/140 [==============================] - 310s 2s/step - loss: 0.1472 - accuracy: 0.9523 - val_loss: 0.1166 - val_accuracy: 0.9654
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9543
# Epoch 00022: val_loss improved from 0.10123 to 0.09977, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 330s 2s/step - loss: 0.1378 - accuracy: 0.9543 - val_loss: 0.0998 - val_accuracy: 0.9717
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9577
# Epoch 00023: val_loss improved from 0.09977 to 0.09512, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 320s 2s/step - loss: 0.1315 - accuracy: 0.9577 - val_loss: 0.0951 - val_accuracy: 0.9703
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9599
# Epoch 00024: val_loss improved from 0.09512 to 0.09225, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 322s 2s/step - loss: 0.1221 - accuracy: 0.9599 - val_loss: 0.0922 - val_accuracy: 0.9746
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9597
# Epoch 00025: val_loss improved from 0.09225 to 0.08512, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 332s 2s/step - loss: 0.1236 - accuracy: 0.9597 - val_loss: 0.0851 - val_accuracy: 0.9763
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9658
# Epoch 00026: val_loss did not improve from 0.08512
# 140/140 [==============================] - 304s 2s/step - loss: 0.1072 - accuracy: 0.9658 - val_loss: 0.0926 - val_accuracy: 0.9712
# Epoch 27/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1139 - accuracy: 0.9618
# Epoch 00027: val_loss improved from 0.08512 to 0.08038, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 306s 2s/step - loss: 0.1139 - accuracy: 0.9618 - val_loss: 0.0804 - val_accuracy: 0.9754
# Epoch 28/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9674
# Epoch 00028: val_loss improved from 0.08038 to 0.06986, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 306s 2s/step - loss: 0.1031 - accuracy: 0.9674 - val_loss: 0.0699 - val_accuracy: 0.9786
# Epoch 29/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.9671
# Epoch 00029: val_loss did not improve from 0.06986
# 140/140 [==============================] - 324s 2s/step - loss: 0.0996 - accuracy: 0.9671 - val_loss: 0.0786 - val_accuracy: 0.9795
# Epoch 30/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0954 - accuracy: 0.9687
# Epoch 00030: val_loss improved from 0.06986 to 0.06438, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 327s 2s/step - loss: 0.0954 - accuracy: 0.9687 - val_loss: 0.0644 - val_accuracy: 0.9812
# Epoch 31/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9684
# Epoch 00031: val_loss did not improve from 0.06438
# 140/140 [==============================] - 303s 2s/step - loss: 0.0953 - accuracy: 0.9684 - val_loss: 0.0778 - val_accuracy: 0.9795
# Epoch 32/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0935 - accuracy: 0.9687
# Epoch 00032: val_loss did not improve from 0.06438
# 140/140 [==============================] - 304s 2s/step - loss: 0.0935 - accuracy: 0.9687 - val_loss: 0.1589 - val_accuracy: 0.9487
# Epoch 33/50
# 140/140 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9671
# Epoch 00033: val_loss did not improve from 0.06438
# Restoring model weights from the end of the best epoch.
# 140/140 [==============================] - 301s 2s/step - loss: 0.0987 - accuracy: 0.9671 - val_loss: 0.0688 - val_accuracy: 0.9819
# Epoch 00033: early stopping

# %% [markdown]
# ## Performance Evalution
#
# Performance will be evaluated on losses and accuracy for trainning and validation. The function below is a generic function that can be used to plot either one based on user input.

# %%
def show_metric(history, metric):
    '''
    history: return value of the .fit, which includes all the history while training the model
    metric: which metric to plot
    '''
    train_metrics = history.history[metric]
    validation_metrics = history.history['val_' + metric]
    
    # make it start from 1
    train_epochs = range(1, len(train_metrics) + 1)
    
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
    plt.plot(train_epochs, train_metrics)
    plt.plot(train_epochs, validation_metrics)
    
    plt.title('Training and Validation '+ metric)
    
    plt.xlabel("Number of Epochs")
    plt.ylabel(metric)
    
    plt.legend(["Training " + metric, "Validation " + metric])
    plt.show()

    
def plot_confusion_matrix(data, labels):
    """Plot confusion matrix using heatmap.
 
    Args:
        data (list of list): List of lists with confusion matrix data.
        labels (list): Labels which will be plotted across x and y axis.
        output_filename (str): Path to output file.
 
    """
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
 
    plt.title("Confusion Matrix")
     
    ax = sns.heatmap(data, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
     
    plt.show()

# %% [markdown]
# #### Basic CNN Architecture

# %%
show_metric(history, "loss")
show_metric(history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 747us/step - loss: 0.9037 - accuracy: 0.7500
# Loss: 0.9037079811096191
# Accuracy: 0.75

# %%
test_generator.reset()
preds = model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c3       0.73      0.80      0.76        10
#           c0       0.90      0.90      0.90        10
#           c1       0.88      0.70      0.78        10
#           c4       0.89      0.80      0.84        10
#           c9       0.80      0.80      0.80        10
#           c2       0.83      1.00      0.91        10
#           c5       0.73      0.80      0.76        10
#           c7       0.71      1.00      0.83        10
#           c6       0.40      0.40      0.40        10
#           c8       0.60      0.30      0.40        10
#
#     accuracy                           0.75       100
#    macro avg       0.75      0.75      0.74       100
# weighted avg       0.75      0.75      0.74       100

# %% [markdown]
# ### Model with transfer learning on pre-trained model

# %%
show_metric(t_history, "loss")
show_metric(t_history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = t_model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5243 - accuracy: 0.4900
# Loss: 2.524338483810425
# Accuracy: 0.49000000953674316

# %%
test_generator.reset()
preds = t_model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c3       0.39      0.70      0.50        10
#           c0       1.00      0.30      0.46        10
#           c1       0.33      0.10      0.15        10
#           c4       1.00      0.30      0.46        10
#           c9       0.67      0.40      0.50        10
#           c2       0.62      1.00      0.77        10
#           c5       0.30      0.30      0.30        10
#           c7       0.62      0.80      0.70        10
#           c6       0.40      0.60      0.48        10
#           c8       0.31      0.40      0.35        10
#
#     accuracy                           0.49       100
#    macro avg       0.56      0.49      0.47       100
# weighted avg       0.56      0.49      0.47       100

# %% [markdown]
# ## Model verification

# %%
def show_test_images(model):
    plt.subplots(figsize=(20, 6))
 
    for i in range(0, 10):              
        plt.subplot(2, 5, i+1)

        choosen_cls=random.choice(os.listdir(TEST_DIR))
        
        path = os.path.join(TEST_DIR, choosen_cls)
        
        choosen_file=random.choice(os.listdir(path))
        
        f_path = os.path.join(path, choosen_file)
        
        image = load_img(path=f_path, target_size=(INPUT_HEIGHT, INPUT_WIDTH))
        input_arr = img_to_array(image)
        input_arr = np.array([input_arr])  # Convert single image to a batch.
        predictions = model.predict(input_arr)
        
        predicted_class = 'c'+str(np.argmax(predictions))
        
        title_str = "Predicted: "+class_dict[predicted_class]
        
        image = mpimg.imread(f_path)
        
        plt.imshow(image)
        plt.title(title_str)
        plt.axis('off')

    plt.show()

# %%
# Load the model
base_model = models.load_model(model_path, compile=True)

show_test_images(base_model)

# %%
vgg19_model = models.load_model(t_model_path, compile = True)

show_test_images(vgg19_model)

# %% [markdown]
# ## Reference
#
# Image classification from scratch: https://keras.io/examples/vision/image_classification_from_scratch/
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# Building powerful image classification models using very little data: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
#
# Tutorial on using Keras flow_from_directory and generators: https://vijayabhaskar96.medium.com/tutorial-image-classification-with-keras-flow-from-directory-and-generators-95f75ebe5720
#
# Losses: https://keras.io/api/losses/
#
# How to use Callbacks in Keras to Visualize, Monitor and Improve your Deep Learning Model: https://medium.com/iitg-ai/how-to-use-callbacks-in-keras-to-visualize-monitor-and-improve-your-deep-learning-model-c9ca37901b28
#
# Image data preprocessing: https://keras.io/api/preprocessing/image/#image_dataset_from_directory-function
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# A Practical Introduction to Keras Callbacks in TensorFlow 2: https://towardsdatascience.com/a-practical-introduction-to-keras-callbacks-in-tensorflow-2-705d0c584966
#
# 4 Pre-Trained CNN Models to Use for Computer Vision with Transfer Learning: https://towardsdatascience.com/4-pre-trained-cnn-models-to-use-for-computer-vision-with-transfer-learning-885cb1b2dfc
#
# Keras Applications: https://keras.io/api/applications/
#
#  A simple example: Confusion Matrix with Keras flow_from_directory.py: https://gist.github.com/RyanAkilos/3808c17f79e77c4117de35aa68447045#file-a-simple-example-confusion-matrix-with-keras-flow_from_directory-py
