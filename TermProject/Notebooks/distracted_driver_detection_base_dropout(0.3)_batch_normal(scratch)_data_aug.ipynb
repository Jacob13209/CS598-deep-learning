# %% [markdown]
# # *Distracted Driver Detection with CNN - Base*
#
# **The objectives of this project are the following:**
# - Implement and train an basic CNN model for distracted driver detection
# - Train a model based on a pre-trained model(VGG-19) via transfer learning
# - Evaluate the performance of both models for their loss and accuracy, including training and validation.
# - Load trained models and use it to run classification on test data that the model never seen before.

# %% [markdown]
# ## Libaries
#
# The main software application being used for this project is *Keras*, including data pre-processing, architecture, model training, training callback functions, and model metrics. *matplotlib* and *seaborn* is also imported for plotting; *os* and *glob* are used for locating and accessing files, etc.

# %%
from keras import layers # layers
from keras import models # models
from keras import optimizers # optimizers for complilation 
from keras import losses # losses 
from keras import metrics # metrics
from keras.utils import plot_model # show the model details in graph

### Callback functions ### 
from keras.callbacks import EarlyStopping  # stop earlier
from keras.callbacks import ReduceLROnPlateau # update the learning rate
from keras.callbacks import ModelCheckpoint # save model,weights

from keras.preprocessing.image import ImageDataGenerator # read images and augumentation
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array
from keras.applications import VGG19
from keras.applications import MobileNet

from PIL import Image
from glob import glob

import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import random

# %%
# check the version of keras
import keras
print(keras.__version__)
# Out:
# 2.4.3

# %%
# do i have a GPU available ??? 
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## Dataset
#
# The dataset was found from *kaggle* at: [https://www.kaggle.com/c/state-farm-distracted-driver-detection/data], which includes labeled driver images; each class is an behavior that was classified, such as, texting, eating, talking on the phone, makeup, reaching behind, etc. It also provides test data that are not labeled, all can be found within same folder.
#
# The 10 classes to predict are:
#
# - c0: safe driving
# - c1: texting - right
# - c2: talking on the phone - right
# - c3: texting - left
# - c4: talking on the phone - left
# - c5: operating the radio
# - c6: drinking
# - c7: reaching behind
# - c8: hair and makeup
# - c9: talking to passenger

# %% [markdown]
# ### Descriptions
#
# The downloaded dataset is a compressed zip package, it includes three part after unzip.
#
# - imgs: driver pictures will be used, and including train and test as sub-folders.
# - driver_imgs_list.csv - csv file that includes the name of driver picturs, subject id(driver), class id(class).
# - sample_submission.csv - sample submission file since this is a kaggle competition. (**I WILL NOT USE THIS FILE**)

# %%
CURR_DIR = os.getcwd()

DATA_DIR = os.path.join(CURR_DIR, "data/state-farm-distracted-driver-detection/")

TRAIN_DIR = os.path.join(DATA_DIR, "imgs/train")  # train dir has sub-classes folders 
TEST_DIR = os.path.join(DATA_DIR, "imgs/test")    # test data folder

DATA_FILE = os.path.join(DATA_DIR, "driver_imgs_list.csv") # train images and according class and driver

# ensure the folder exist for saving the models
MODEL_DIR = os.path.join(CURR_DIR, "saved_models")

# create the model dir if not exist
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# define the class and its according description 

# classes 
classes = {'c0','c1','c2','c3','c4','c5','c6','c7','c8','c9'}

# {folder name}:{description}
class_dict = {'c0': 'Safe driving', 
              'c1': 'Texting - right', 
              'c2': 'Talking on the phone - right', 
              'c3': 'Texting - left', 
              'c4': 'Talking on the phone - left', 
              'c5': 'Operating the radio', 
              'c6': 'Drinking', 
              'c7': 'Reaching behind', 
              'c8': 'Hair and makeup', 
              'c9': 'Talking to passenger'}

# %% [markdown]
# #### Parameters setup
#
# Before data pre-processing, I will define the input shape(target height and width), and number of training epochs, and the batch size that helps to reduce the memory usage when running on less powerful platforms.

# %%
#INPUT_WIDTH = 32
#INPUT_HEIGHT = 32

INPUT_WIDTH = 64
INPUT_HEIGHT = 64

# %%
#EPOCHES = 5
#SIZE = 32

EPOCHES = 50
BATCH_SIZE = 128

# %% [markdown]
# #### Data Pre-Processing
#
# With *Keras*, image data processing has become much easier. Instead of reading subfolers for all files, load pictures and covert to numpy array, *Keras* provides API calls, *flow_from_directory*, which will read data from specified directory and categorize to different classes, load with resizing, etc, with the usage of *ImageDataGenerator*.

# %%
# with data augmentation 
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   brightness_range=[0.4, 1.2],
                                   shear_range=0.2,
                                   zoom_range=0.3,
                                   validation_split=0.2)

train_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                    target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                    classes=None, 
                                                    class_mode='categorical',
                                                    batch_size=BATCH_SIZE, 
                                                    shuffle=True, 
                                                    subset='training')

validation_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                         target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                         classes=None, 
                                                         class_mode='categorical',
                                                         batch_size=BATCH_SIZE, 
                                                         shuffle=True, 
                                                         subset='validation')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(TEST_DIR, 
                                                  target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=False, 
                                                  class_mode='categorical')
# Out:
# Found 17943 images belonging to 10 classes.
# Found 4481 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
# calculate the steps for training and validation
TRAIN_STEPS = train_generator.samples // BATCH_SIZE
VALIDATION_STEPS = validation_generator.samples // BATCH_SIZE

# %% [markdown]
# ## Basic CNN Architeture

# %%
model = models.Sequential()

# filters, stride, input size, chanel 
model.add(layers.Conv2D(32, (5,5), padding='same', input_shape=(INPUT_HEIGHT, INPUT_WIDTH, 3)))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(32) * height * width 

model.add(layers.Conv2D(64, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(64) * height/2 * width/2 

model.add(layers.Conv2D(128, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(128) * height/4 * width/4 

model.add(layers.Flatten())

model.add(layers.Dropout(0.3))

model.add(layers.Dense(256))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.Dense(10))

model.add(layers.BatchNormalization())

model.add(layers.Activation("softmax"))

# %%
# use categorical crossentropy since our data is multi-class classification
#loss_func = losses.CategoricalCrossentropy(from_logits=False, name="categorical_crossentropy")

# outperforms others in practice, RMSprop + Momentum
#opt_func = optimizers.Adam(lr=0.0001)

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
# check the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10)                40
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 2,360,562
# Trainable params: 2,359,582
# Non-trainable params: 980
# _________________________________________________________________

# %%
# plot the model in picture format to visualize how layers are connected with according input/output size
plot_model(model, to_file="basic_cnn_model.png", show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Callback functions
#
# Callback functions are provided by *Keras*, which will be executed during the training of the model and can be used for different purposes; In this project, I will use the following three callback APIS:
# - EarlyStopping: stop the training earlier if the specified metric stopped improving
# - ReduceLROnPlateau: adjust the learning rate when the specified metric stopped improving
# - ModelCheckpoint: save the model weights and model each training epoch

# %%
# define callback functions
# 1: early stopping 
# https://keras.io/api/callbacks/early_stopping/
early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

# 2: reduce the learning rate when a metric has stopped improving 
# https://keras.io/api/callbacks/reduce_lr_on_plateau/
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # monitored metric
    factor=0.2,   # new lr = factor * lr
    patience=2,   # number of epochs 
    min_lr=0.001,  # min lr
    verbose=1
)

# 3: save model or model weights
# https://keras.io/api/callbacks/model_checkpoint/
model_path = MODEL_DIR + '/distracted_driver_detection_base.h5'
model_cp = ModelCheckpoint(
    filepath=model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, model_cp]
#callbacks = []

# %%
history=model.fit(train_generator, 
                  steps_per_epoch = TRAIN_STEPS, 
                  epochs = EPOCHES,
                  verbose = 1,
                  validation_data = validation_generator,
                  validation_steps = VALIDATION_STEPS,
                  callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 1.9469 - accuracy: 0.3087
# Epoch 00001: val_loss improved from inf to 2.65810, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 176s 1s/step - loss: 1.9469 - accuracy: 0.3087 - val_loss: 2.6581 - val_accuracy: 0.1170
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3663 - accuracy: 0.5636
# Epoch 00002: val_loss improved from 2.65810 to 2.40100, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 170s 1s/step - loss: 1.3663 - accuracy: 0.5636 - val_loss: 2.4010 - val_accuracy: 0.1714
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 1.0265 - accuracy: 0.7060
# Epoch 00003: val_loss improved from 2.40100 to 1.53901, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 165s 1s/step - loss: 1.0265 - accuracy: 0.7060 - val_loss: 1.5390 - val_accuracy: 0.5025
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.8111 - accuracy: 0.7857
# Epoch 00004: val_loss improved from 1.53901 to 1.10812, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 167s 1s/step - loss: 0.8111 - accuracy: 0.7857 - val_loss: 1.1081 - val_accuracy: 0.6355
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6696 - accuracy: 0.8274
# Epoch 00005: val_loss improved from 1.10812 to 0.67039, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 171s 1s/step - loss: 0.6696 - accuracy: 0.8274 - val_loss: 0.6704 - val_accuracy: 0.8205
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.5665 - accuracy: 0.8592
# Epoch 00006: val_loss did not improve from 0.67039
# 140/140 [==============================] - 170s 1s/step - loss: 0.5665 - accuracy: 0.8592 - val_loss: 0.7915 - val_accuracy: 0.7757
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4997 - accuracy: 0.8736
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00007: val_loss did not improve from 0.67039
# 140/140 [==============================] - 172s 1s/step - loss: 0.4997 - accuracy: 0.8736 - val_loss: 0.7768 - val_accuracy: 0.7540
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4360 - accuracy: 0.8917
# Epoch 00008: val_loss improved from 0.67039 to 0.42949, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 179s 1s/step - loss: 0.4360 - accuracy: 0.8917 - val_loss: 0.4295 - val_accuracy: 0.8967
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3827 - accuracy: 0.9079
# Epoch 00009: val_loss did not improve from 0.42949
# 140/140 [==============================] - 181s 1s/step - loss: 0.3827 - accuracy: 0.9079 - val_loss: 0.5503 - val_accuracy: 0.8433
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3432 - accuracy: 0.9196
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00010: val_loss did not improve from 0.42949
# 140/140 [==============================] - 177s 1s/step - loss: 0.3432 - accuracy: 0.9196 - val_loss: 0.5773 - val_accuracy: 0.8306
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3088 - accuracy: 0.9248
# Epoch 00011: val_loss improved from 0.42949 to 0.42803, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 177s 1s/step - loss: 0.3088 - accuracy: 0.9248 - val_loss: 0.4280 - val_accuracy: 0.8721
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2882 - accuracy: 0.9301
# Epoch 00012: val_loss did not improve from 0.42803
# 140/140 [==============================] - 185s 1s/step - loss: 0.2882 - accuracy: 0.9301 - val_loss: 0.5099 - val_accuracy: 0.8368
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2627 - accuracy: 0.9371
# Epoch 00013: val_loss improved from 0.42803 to 0.30395, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 189s 1s/step - loss: 0.2627 - accuracy: 0.9371 - val_loss: 0.3040 - val_accuracy: 0.9208
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2459 - accuracy: 0.9416
# Epoch 00014: val_loss did not improve from 0.30395
# 140/140 [==============================] - 191s 1s/step - loss: 0.2459 - accuracy: 0.9416 - val_loss: 0.5045 - val_accuracy: 0.8379
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.9436
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00015: val_loss did not improve from 0.30395
# 140/140 [==============================] - 190s 1s/step - loss: 0.2331 - accuracy: 0.9436 - val_loss: 0.4213 - val_accuracy: 0.8770
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2074 - accuracy: 0.9498Restoring model weights from the end of the best epoch.
#
# Epoch 00016: val_loss did not improve from 0.30395
# 140/140 [==============================] - 192s 1s/step - loss: 0.2074 - accuracy: 0.9498 - val_loss: 0.4225 - val_accuracy: 0.8703
# Epoch 00016: early stopping

# %% [markdown]
# ## Transfer learning on Pre-Trained Model (VGG-19)
#
# VGG-19 architecture is being used for this experienment.

# %%
conv_base = VGG19(weights="imagenet", 
                  include_top = False, # exclude the top three fully connected layer
                  input_shape = (INPUT_HEIGHT, INPUT_WIDTH, 3), # configure the input shape, default is 224*224*3
                 )

# %%
conv_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = conv_base.output

x = layers.Flatten()(x)

x = layers.Dropout(0.3)(x)

x = layers.Dense(256, activation='relu')(x)

predictions = layers.Dense(10, activation='softmax')(x)

# %%
t_model= models.Model(inputs=conv_base.input, outputs=predictions)

# %%
for layer in conv_base.layers:
    layer.trainable = False

#for layer in t_model.layers[:10]:
#    layer.trainable = False

# %%
#t_model.compile(loss='categorical_crossentropy', 
#                #optimizer='adam', 
#                optimizer=optimizers.Adam(lr=0.0001),
#                metrics=['accuracy'])

t_model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
t_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 20,551,498
# Trainable params: 527,114
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(t_model, to_file="transfered_model_vgg19.png", show_shapes=True, show_layer_names=True)

# %%
t_model_path = MODEL_DIR + '/distracted_driver_detection_vgg19.h5'
model_cp = ModelCheckpoint(
    filepath=t_model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

callbacks = [model_cp, early_stop]

# %%
# reset data generator
train_generator.reset()
validation_generator.reset()

t_history=t_model.fit(train_generator, 
                      steps_per_epoch = TRAIN_STEPS, 
                      epochs = EPOCHES,
                      verbose = 1,
                      validation_data = validation_generator,
                      validation_steps = VALIDATION_STEPS,
                      callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 2.0884 - accuracy: 0.2486
# Epoch 00001: val_loss improved from inf to 1.91336, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 337s 2s/step - loss: 2.0884 - accuracy: 0.2486 - val_loss: 1.9134 - val_accuracy: 0.2877
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8544 - accuracy: 0.3352
# Epoch 00002: val_loss improved from 1.91336 to 1.68995, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 337s 2s/step - loss: 1.8544 - accuracy: 0.3352 - val_loss: 1.6900 - val_accuracy: 0.3922
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7885 - accuracy: 0.3621
# Epoch 00003: val_loss improved from 1.68995 to 1.66838, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 327s 2s/step - loss: 1.7885 - accuracy: 0.3621 - val_loss: 1.6684 - val_accuracy: 0.4183
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7571 - accuracy: 0.3743
# Epoch 00004: val_loss improved from 1.66838 to 1.61696, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 313s 2s/step - loss: 1.7571 - accuracy: 0.3743 - val_loss: 1.6170 - val_accuracy: 0.4275
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7129 - accuracy: 0.3875
# Epoch 00005: val_loss improved from 1.61696 to 1.60727, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 319s 2s/step - loss: 1.7129 - accuracy: 0.3875 - val_loss: 1.6073 - val_accuracy: 0.4283
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6982 - accuracy: 0.3982
# Epoch 00006: val_loss improved from 1.60727 to 1.52865, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 314s 2s/step - loss: 1.6982 - accuracy: 0.3982 - val_loss: 1.5286 - val_accuracy: 0.4721
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6579 - accuracy: 0.4113
# Epoch 00007: val_loss did not improve from 1.52865
# 140/140 [==============================] - 313s 2s/step - loss: 1.6579 - accuracy: 0.4113 - val_loss: 1.5305 - val_accuracy: 0.4723
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6395 - accuracy: 0.4171
# Epoch 00008: val_loss improved from 1.52865 to 1.51528, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 330s 2s/step - loss: 1.6395 - accuracy: 0.4171 - val_loss: 1.5153 - val_accuracy: 0.4719
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6137 - accuracy: 0.4269
# Epoch 00009: val_loss improved from 1.51528 to 1.48795, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 314s 2s/step - loss: 1.6137 - accuracy: 0.4269 - val_loss: 1.4880 - val_accuracy: 0.4913
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5974 - accuracy: 0.4341
# Epoch 00010: val_loss improved from 1.48795 to 1.47743, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 311s 2s/step - loss: 1.5974 - accuracy: 0.4341 - val_loss: 1.4774 - val_accuracy: 0.4746
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5752 - accuracy: 0.4420
# Epoch 00011: val_loss improved from 1.47743 to 1.42043, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 312s 2s/step - loss: 1.5752 - accuracy: 0.4420 - val_loss: 1.4204 - val_accuracy: 0.4996
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5604 - accuracy: 0.4497
# Epoch 00012: val_loss did not improve from 1.42043
# 140/140 [==============================] - 304s 2s/step - loss: 1.5604 - accuracy: 0.4497 - val_loss: 1.4274 - val_accuracy: 0.5020
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5363 - accuracy: 0.4585
# Epoch 00013: val_loss improved from 1.42043 to 1.38083, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.5363 - accuracy: 0.4585 - val_loss: 1.3808 - val_accuracy: 0.5192
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5347 - accuracy: 0.4587
# Epoch 00014: val_loss did not improve from 1.38083
# 140/140 [==============================] - 302s 2s/step - loss: 1.5347 - accuracy: 0.4587 - val_loss: 1.3934 - val_accuracy: 0.5185
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5240 - accuracy: 0.4668
# Epoch 00015: val_loss improved from 1.38083 to 1.37894, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 302s 2s/step - loss: 1.5240 - accuracy: 0.4668 - val_loss: 1.3789 - val_accuracy: 0.5192
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4852 - accuracy: 0.4763
# Epoch 00016: val_loss improved from 1.37894 to 1.36158, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 303s 2s/step - loss: 1.4852 - accuracy: 0.4763 - val_loss: 1.3616 - val_accuracy: 0.5292
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4851 - accuracy: 0.4743
# Epoch 00017: val_loss improved from 1.36158 to 1.35078, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.4851 - accuracy: 0.4743 - val_loss: 1.3508 - val_accuracy: 0.5384
# Epoch 18/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4729 - accuracy: 0.4823
# Epoch 00018: val_loss improved from 1.35078 to 1.32145, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.4729 - accuracy: 0.4823 - val_loss: 1.3214 - val_accuracy: 0.5502
# Epoch 19/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4615 - accuracy: 0.4854
# Epoch 00019: val_loss improved from 1.32145 to 1.30741, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 1.4615 - accuracy: 0.4854 - val_loss: 1.3074 - val_accuracy: 0.5471
# Epoch 20/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4551 - accuracy: 0.4850
# Epoch 00020: val_loss did not improve from 1.30741
# 140/140 [==============================] - 308s 2s/step - loss: 1.4551 - accuracy: 0.4850 - val_loss: 1.3451 - val_accuracy: 0.5408
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4360 - accuracy: 0.4934
# Epoch 00021: val_loss improved from 1.30741 to 1.27621, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 311s 2s/step - loss: 1.4360 - accuracy: 0.4934 - val_loss: 1.2762 - val_accuracy: 0.5638
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4382 - accuracy: 0.4899
# Epoch 00022: val_loss did not improve from 1.27621
# 140/140 [==============================] - 308s 2s/step - loss: 1.4382 - accuracy: 0.4899 - val_loss: 1.2851 - val_accuracy: 0.5625
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4154 - accuracy: 0.4983
# Epoch 00023: val_loss did not improve from 1.27621
# 140/140 [==============================] - 305s 2s/step - loss: 1.4154 - accuracy: 0.4983 - val_loss: 1.2861 - val_accuracy: 0.5473
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3997 - accuracy: 0.5031
# Epoch 00024: val_loss improved from 1.27621 to 1.24520, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 1.3997 - accuracy: 0.5031 - val_loss: 1.2452 - val_accuracy: 0.5824
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4059 - accuracy: 0.5051
# Epoch 00025: val_loss did not improve from 1.24520
# 140/140 [==============================] - 303s 2s/step - loss: 1.4059 - accuracy: 0.5051 - val_loss: 1.2842 - val_accuracy: 0.5587
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3711 - accuracy: 0.5097
# Epoch 00026: val_loss improved from 1.24520 to 1.21807, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 306s 2s/step - loss: 1.3711 - accuracy: 0.5097 - val_loss: 1.2181 - val_accuracy: 0.5813
# Epoch 27/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3752 - accuracy: 0.5156
# Epoch 00027: val_loss did not improve from 1.21807
# 140/140 [==============================] - 306s 2s/step - loss: 1.3752 - accuracy: 0.5156 - val_loss: 1.2461 - val_accuracy: 0.5723
# Epoch 28/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3625 - accuracy: 0.5244
# Epoch 00028: val_loss did not improve from 1.21807
# 140/140 [==============================] - 305s 2s/step - loss: 1.3625 - accuracy: 0.5244 - val_loss: 1.2320 - val_accuracy: 0.5732
# Epoch 29/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3505 - accuracy: 0.5260
# Epoch 00029: val_loss improved from 1.21807 to 1.21560, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 1.3505 - accuracy: 0.5260 - val_loss: 1.2156 - val_accuracy: 0.5902
# Epoch 30/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3409 - accuracy: 0.5252
# Epoch 00030: val_loss improved from 1.21560 to 1.20277, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 303s 2s/step - loss: 1.3409 - accuracy: 0.5252 - val_loss: 1.2028 - val_accuracy: 0.5877
# Epoch 31/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3556 - accuracy: 0.5241
# Epoch 00031: val_loss did not improve from 1.20277
# 140/140 [==============================] - 299s 2s/step - loss: 1.3556 - accuracy: 0.5241 - val_loss: 1.2154 - val_accuracy: 0.5792
# Epoch 32/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3438 - accuracy: 0.5239
# Epoch 00032: val_loss improved from 1.20277 to 1.17666, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 1.3438 - accuracy: 0.5239 - val_loss: 1.1767 - val_accuracy: 0.5987
# Epoch 33/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3255 - accuracy: 0.5329
# Epoch 00033: val_loss improved from 1.17666 to 1.15024, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 299s 2s/step - loss: 1.3255 - accuracy: 0.5329 - val_loss: 1.1502 - val_accuracy: 0.6174
# Epoch 34/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3320 - accuracy: 0.5308
# Epoch 00034: val_loss did not improve from 1.15024
# 140/140 [==============================] - 298s 2s/step - loss: 1.3320 - accuracy: 0.5308 - val_loss: 1.1826 - val_accuracy: 0.6007
# Epoch 35/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3248 - accuracy: 0.5393
# Epoch 00035: val_loss did not improve from 1.15024
# 140/140 [==============================] - 300s 2s/step - loss: 1.3248 - accuracy: 0.5393 - val_loss: 1.1679 - val_accuracy: 0.5951
# Epoch 36/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3078 - accuracy: 0.5389
# Epoch 00036: val_loss improved from 1.15024 to 1.13682, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 300s 2s/step - loss: 1.3078 - accuracy: 0.5389 - val_loss: 1.1368 - val_accuracy: 0.6103
# Epoch 37/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2862 - accuracy: 0.5459
# Epoch 00037: val_loss did not improve from 1.13682
# 140/140 [==============================] - 310s 2s/step - loss: 1.2862 - accuracy: 0.5459 - val_loss: 1.1650 - val_accuracy: 0.6054
# Epoch 38/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3122 - accuracy: 0.5398
# Epoch 00038: val_loss improved from 1.13682 to 1.13431, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 303s 2s/step - loss: 1.3122 - accuracy: 0.5398 - val_loss: 1.1343 - val_accuracy: 0.6089
# Epoch 39/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2852 - accuracy: 0.5466
# Epoch 00039: val_loss improved from 1.13431 to 1.11429, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.2852 - accuracy: 0.5466 - val_loss: 1.1143 - val_accuracy: 0.6152
# Epoch 40/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2879 - accuracy: 0.5445
# Epoch 00040: val_loss did not improve from 1.11429
# 140/140 [==============================] - 304s 2s/step - loss: 1.2879 - accuracy: 0.5445 - val_loss: 1.1210 - val_accuracy: 0.6192
# Epoch 41/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2902 - accuracy: 0.5475
# Epoch 00041: val_loss improved from 1.11429 to 1.08988, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.2902 - accuracy: 0.5475 - val_loss: 1.0899 - val_accuracy: 0.6408
# Epoch 42/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2787 - accuracy: 0.5466
# Epoch 00042: val_loss did not improve from 1.08988
# 140/140 [==============================] - 302s 2s/step - loss: 1.2787 - accuracy: 0.5466 - val_loss: 1.1313 - val_accuracy: 0.6138
# Epoch 43/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2721 - accuracy: 0.5541
# Epoch 00043: val_loss did not improve from 1.08988
# 140/140 [==============================] - 302s 2s/step - loss: 1.2721 - accuracy: 0.5541 - val_loss: 1.0976 - val_accuracy: 0.6342
# Epoch 44/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2609 - accuracy: 0.5545
# Epoch 00044: val_loss improved from 1.08988 to 1.08289, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 301s 2s/step - loss: 1.2609 - accuracy: 0.5545 - val_loss: 1.0829 - val_accuracy: 0.6429
# Epoch 45/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2682 - accuracy: 0.5558
# Epoch 00045: val_loss improved from 1.08289 to 1.08289, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 302s 2s/step - loss: 1.2682 - accuracy: 0.5558 - val_loss: 1.0829 - val_accuracy: 0.6350
# Epoch 46/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2545 - accuracy: 0.5577
# Epoch 00046: val_loss improved from 1.08289 to 1.08127, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 302s 2s/step - loss: 1.2545 - accuracy: 0.5577 - val_loss: 1.0813 - val_accuracy: 0.6330
# Epoch 47/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2386 - accuracy: 0.5628
# Epoch 00047: val_loss did not improve from 1.08127
# 140/140 [==============================] - 303s 2s/step - loss: 1.2386 - accuracy: 0.5628 - val_loss: 1.1015 - val_accuracy: 0.6187
# Epoch 48/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2377 - accuracy: 0.5589
# Epoch 00048: val_loss improved from 1.08127 to 1.07580, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 301s 2s/step - loss: 1.2377 - accuracy: 0.5589 - val_loss: 1.0758 - val_accuracy: 0.6408
# Epoch 49/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2414 - accuracy: 0.5685
# Epoch 00049: val_loss improved from 1.07580 to 1.04537, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 301s 2s/step - loss: 1.2414 - accuracy: 0.5685 - val_loss: 1.0454 - val_accuracy: 0.6522
# Epoch 50/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2309 - accuracy: 0.5695
# Epoch 00050: val_loss did not improve from 1.04537
# 140/140 [==============================] - 302s 2s/step - loss: 1.2309 - accuracy: 0.5695 - val_loss: 1.0716 - val_accuracy: 0.6359

# %% [markdown]
# ## Performance Evalution
#
# Performance will be evaluated on losses and accuracy for trainning and validation. The function below is a generic function that can be used to plot either one based on user input.

# %%
def show_metric(history, metric):
    '''
    history: return value of the .fit, which includes all the history while training the model
    metric: which metric to plot
    '''
    train_metrics = history.history[metric]
    validation_metrics = history.history['val_' + metric]
    
    # make it start from 1
    train_epochs = range(1, len(train_metrics) + 1)
    
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
    plt.plot(train_epochs, train_metrics)
    plt.plot(train_epochs, validation_metrics)
    
    plt.title('Training and Validation '+ metric)
    
    plt.xlabel("Number of Epochs")
    plt.ylabel(metric)
    
    plt.legend(["Training " + metric, "Validation " + metric])
    plt.show()

    
def plot_confusion_matrix(data, labels):
    """Plot confusion matrix using heatmap.
 
    Args:
        data (list of list): List of lists with confusion matrix data.
        labels (list): Labels which will be plotted across x and y axis.
        output_filename (str): Path to output file.
 
    """
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
 
    plt.title("Confusion Matrix")
     
    ax = sns.heatmap(data, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
     
    plt.show()

# %% [markdown]
# #### Basic CNN Architecture

# %%
show_metric(history, "loss")
show_metric(history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6639 - accuracy: 0.8100
# Loss: 0.6639305353164673
# Accuracy: 0.8100000023841858

# %%
test_generator.reset()
preds = model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c8       0.86      0.60      0.71        10
#           c7       0.83      1.00      0.91        10
#           c3       0.82      0.90      0.86        10
#           c9       0.91      1.00      0.95        10
#           c1       0.90      0.90      0.90        10
#           c5       1.00      1.00      1.00        10
#           c4       0.75      0.60      0.67        10
#           c2       0.77      1.00      0.87        10
#           c0       0.50      0.50      0.50        10
#           c6       0.75      0.60      0.67        10
#
#     accuracy                           0.81       100
#    macro avg       0.81      0.81      0.80       100
# weighted avg       0.81      0.81      0.80       100

# %% [markdown]
# ### Model with transfer learning on pre-trained model

# %%
show_metric(t_history, "loss")
show_metric(t_history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = t_model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5356 - accuracy: 0.4600
# Loss: 1.5355585813522339
# Accuracy: 0.46000000834465027

# %%
test_generator.reset()
preds = t_model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c8       0.30      0.30      0.30        10
#           c7       0.57      0.40      0.47        10
#           c3       0.46      0.60      0.52        10
#           c9       1.00      0.20      0.33        10
#           c1       0.25      0.10      0.14        10
#           c5       0.89      0.80      0.84        10
#           c4       0.38      0.50      0.43        10
#           c2       0.50      0.80      0.62        10
#           c0       0.71      0.50      0.59        10
#           c6       0.21      0.40      0.28        10
#
#     accuracy                           0.46       100
#    macro avg       0.53      0.46      0.45       100
# weighted avg       0.53      0.46      0.45       100

# %% [markdown]
# ## Model verification

# %%
def show_test_images(model):
    plt.subplots(figsize=(20, 6))
 
    for i in range(0, 10):              
        plt.subplot(2, 5, i+1)

        choosen_cls=random.choice(os.listdir(TEST_DIR))
        
        path = os.path.join(TEST_DIR, choosen_cls)
        
        choosen_file=random.choice(os.listdir(path))
        
        f_path = os.path.join(path, choosen_file)
        
        image = load_img(path=f_path, target_size=(INPUT_HEIGHT, INPUT_WIDTH))
        input_arr = img_to_array(image)
        input_arr = np.array([input_arr])  # Convert single image to a batch.
        predictions = model.predict(input_arr)
        
        predicted_class = 'c'+str(np.argmax(predictions))
        
        title_str = "Predicted: "+class_dict[predicted_class]
        
        image = mpimg.imread(f_path)
        
        plt.imshow(image)
        plt.title(title_str)
        plt.axis('off')

    plt.show()

# %%
# Load the model
base_model = models.load_model(model_path, compile=True)

show_test_images(base_model)

# %%
vgg19_model = models.load_model(t_model_path, compile = True)

show_test_images(vgg19_model)

# %% [markdown]
# ## Reference
#
# Image classification from scratch: https://keras.io/examples/vision/image_classification_from_scratch/
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# Building powerful image classification models using very little data: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
#
# Tutorial on using Keras flow_from_directory and generators: https://vijayabhaskar96.medium.com/tutorial-image-classification-with-keras-flow-from-directory-and-generators-95f75ebe5720
#
# Losses: https://keras.io/api/losses/
#
# How to use Callbacks in Keras to Visualize, Monitor and Improve your Deep Learning Model: https://medium.com/iitg-ai/how-to-use-callbacks-in-keras-to-visualize-monitor-and-improve-your-deep-learning-model-c9ca37901b28
#
# Image data preprocessing: https://keras.io/api/preprocessing/image/#image_dataset_from_directory-function
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# A Practical Introduction to Keras Callbacks in TensorFlow 2: https://towardsdatascience.com/a-practical-introduction-to-keras-callbacks-in-tensorflow-2-705d0c584966
#
# 4 Pre-Trained CNN Models to Use for Computer Vision with Transfer Learning: https://towardsdatascience.com/4-pre-trained-cnn-models-to-use-for-computer-vision-with-transfer-learning-885cb1b2dfc
#
# Keras Applications: https://keras.io/api/applications/
#
#  A simple example: Confusion Matrix with Keras flow_from_directory.py: https://gist.github.com/RyanAkilos/3808c17f79e77c4117de35aa68447045#file-a-simple-example-confusion-matrix-with-keras-flow_from_directory-py
