# %% [markdown]
# # *Distracted Driver Detection with CNN - Base*
#
# **The objectives of this project are the following:**
# - Implement and train an basic CNN model for distracted driver detection
# - Train a model based on a pre-trained model(VGG-19) via transfer learning
# - Evaluate the performance of both models for their loss and accuracy, including training and validation.
# - Load trained models and use it to run classification on test data that the model never seen before.

# %% [markdown]
# ## Libaries
#
# The main software application being used for this project is *Keras*, including data pre-processing, architecture, model training, training callback functions, and model metrics. *matplotlib* and *seaborn* is also imported for plotting; *os* and *glob* are used for locating and accessing files, etc.

# %%
from keras import layers # layers
from keras import models # models
from keras import optimizers # optimizers for complilation 
from keras import losses # losses 
from keras import metrics # metrics
from keras.utils import plot_model # show the model details in graph

### Callback functions ### 
from keras.callbacks import EarlyStopping  # stop earlier
from keras.callbacks import ReduceLROnPlateau # update the learning rate
from keras.callbacks import ModelCheckpoint # save model,weights

from keras.preprocessing.image import ImageDataGenerator # read images and augumentation
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array
from keras.applications import VGG19
from keras.applications import MobileNet

from PIL import Image
from glob import glob

import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import random

# %%
# check the version of keras
import keras
print(keras.__version__)
# Out:
# 2.4.3

# %%
# do i have a GPU available ??? 
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## Dataset
#
# The dataset was found from *kaggle* at: [https://www.kaggle.com/c/state-farm-distracted-driver-detection/data], which includes labeled driver images; each class is an behavior that was classified, such as, texting, eating, talking on the phone, makeup, reaching behind, etc. It also provides test data that are not labeled, all can be found within same folder.
#
# The 10 classes to predict are:
#
# - c0: safe driving
# - c1: texting - right
# - c2: talking on the phone - right
# - c3: texting - left
# - c4: talking on the phone - left
# - c5: operating the radio
# - c6: drinking
# - c7: reaching behind
# - c8: hair and makeup
# - c9: talking to passenger

# %% [markdown]
# ### Descriptions
#
# The downloaded dataset is a compressed zip package, it includes three part after unzip.
#
# - imgs: driver pictures will be used, and including train and test as sub-folders.
# - driver_imgs_list.csv - csv file that includes the name of driver picturs, subject id(driver), class id(class).
# - sample_submission.csv - sample submission file since this is a kaggle competition. (**I WILL NOT USE THIS FILE**)

# %%
CURR_DIR = os.getcwd()

DATA_DIR = os.path.join(CURR_DIR, "data/state-farm-distracted-driver-detection/")

TRAIN_DIR = os.path.join(DATA_DIR, "imgs/train")  # train dir has sub-classes folders 
TEST_DIR = os.path.join(DATA_DIR, "imgs/test")    # test data folder

DATA_FILE = os.path.join(DATA_DIR, "driver_imgs_list.csv") # train images and according class and driver

# ensure the folder exist for saving the models
MODEL_DIR = os.path.join(CURR_DIR, "saved_models")

# create the model dir if not exist
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# define the class and its according description 

# classes 
classes = {'c0','c1','c2','c3','c4','c5','c6','c7','c8','c9'}

# {folder name}:{description}
class_dict = {'c0': 'Safe driving', 
              'c1': 'Texting - right', 
              'c2': 'Talking on the phone - right', 
              'c3': 'Texting - left', 
              'c4': 'Talking on the phone - left', 
              'c5': 'Operating the radio', 
              'c6': 'Drinking', 
              'c7': 'Reaching behind', 
              'c8': 'Hair and makeup', 
              'c9': 'Talking to passenger'}

# %% [markdown]
# #### Parameters setup
#
# Before data pre-processing, I will define the input shape(target height and width), and number of training epochs, and the batch size that helps to reduce the memory usage when running on less powerful platforms.

# %%
#INPUT_WIDTH = 32
#INPUT_HEIGHT = 32

INPUT_WIDTH = 64
INPUT_HEIGHT = 64

# %%
#EPOCHES = 5
#SIZE = 32

EPOCHES = 50
BATCH_SIZE = 128

# %% [markdown]
# #### Data Pre-Processing
#
# With *Keras*, image data processing has become much easier. Instead of reading subfolers for all files, load pictures and covert to numpy array, *Keras* provides API calls, *flow_from_directory*, which will read data from specified directory and categorize to different classes, load with resizing, etc, with the usage of *ImageDataGenerator*.

# %%
# with data augmentation 
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   brightness_range=[0.4, 1.2],
                                   shear_range=0.2,
                                   zoom_range=0.3,
                                   validation_split=0.2)

train_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                    target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                    classes=None, 
                                                    class_mode='categorical',
                                                    batch_size=BATCH_SIZE, 
                                                    shuffle=True, 
                                                    subset='training')

validation_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                         target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                         classes=None, 
                                                         class_mode='categorical',
                                                         batch_size=BATCH_SIZE, 
                                                         shuffle=True, 
                                                         subset='validation')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(TEST_DIR, 
                                                  target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=False, 
                                                  class_mode='categorical')
# Out:
# Found 17943 images belonging to 10 classes.
# Found 4481 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
# calculate the steps for training and validation
TRAIN_STEPS = train_generator.samples // BATCH_SIZE
VALIDATION_STEPS = validation_generator.samples // BATCH_SIZE

# %% [markdown]
# ## Basic CNN Architeture

# %%
model = models.Sequential()

# filters, stride, input size, chanel 
model.add(layers.Conv2D(32, (5,5), padding='same', input_shape=(INPUT_HEIGHT, INPUT_WIDTH, 3)))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(32) * height * width 

model.add(layers.Conv2D(64, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(64) * height/2 * width/2 

model.add(layers.Conv2D(128, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(128) * height/4 * width/4 

model.add(layers.Flatten())

model.add(layers.Dropout(0.3))

model.add(layers.Dense(256))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.Dense(10))

model.add(layers.BatchNormalization())

model.add(layers.Activation("softmax"))

# %%
# use categorical crossentropy since our data is multi-class classification
#loss_func = losses.CategoricalCrossentropy(from_logits=False, name="categorical_crossentropy")

# outperforms others in practice, RMSprop + Momentum
#opt_func = optimizers.Adam(lr=0.0001)

model.compile(loss='categorical_crossentropy', 
              #optimizer='adam', 
              optimizer=optimizers.Adam(lr=0.001),
              metrics=['accuracy'])

#model.compile(loss=loss_func, 
#              optimizer=opt_func, 
#              metrics=['accuracy'])

# %%
# check the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10)                40
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 2,360,562
# Trainable params: 2,359,582
# Non-trainable params: 980
# _________________________________________________________________

# %%
# plot the model in picture format to visualize how layers are connected with according input/output size
plot_model(model, to_file="basic_cnn_model.png", show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Callback functions
#
# Callback functions are provided by *Keras*, which will be executed during the training of the model and can be used for different purposes; In this project, I will use the following three callback APIS:
# - EarlyStopping: stop the training earlier if the specified metric stopped improving
# - ReduceLROnPlateau: adjust the learning rate when the specified metric stopped improving
# - ModelCheckpoint: save the model weights and model each training epoch

# %%
# define callback functions
# 1: early stopping 
# https://keras.io/api/callbacks/early_stopping/
early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

# 2: reduce the learning rate when a metric has stopped improving 
# https://keras.io/api/callbacks/reduce_lr_on_plateau/
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # monitored metric
    factor=0.2,   # new lr = factor * lr
    patience=2,   # number of epochs 
    min_lr=0.001,  # min lr
    verbose=1
)

# 3: save model or model weights
# https://keras.io/api/callbacks/model_checkpoint/
model_path = MODEL_DIR + '/distracted_driver_detection_base.h5'
model_cp = ModelCheckpoint(
    filepath=model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, model_cp]
#callbacks = []

# %%
history=model.fit(train_generator, 
                  steps_per_epoch = TRAIN_STEPS, 
                  epochs = EPOCHES,
                  verbose = 1,
                  validation_data = validation_generator,
                  validation_steps = VALIDATION_STEPS,
                  callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 1.9371 - accuracy: 0.3031
# Epoch 00001: val_loss improved from inf to 2.35246, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 172s 1s/step - loss: 1.9371 - accuracy: 0.3031 - val_loss: 2.3525 - val_accuracy: 0.1754
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3697 - accuracy: 0.5602
# Epoch 00002: val_loss improved from 2.35246 to 2.23503, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 174s 1s/step - loss: 1.3697 - accuracy: 0.5602 - val_loss: 2.2350 - val_accuracy: 0.1913
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 1.0154 - accuracy: 0.7122
# Epoch 00003: val_loss improved from 2.23503 to 1.75744, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 172s 1s/step - loss: 1.0154 - accuracy: 0.7122 - val_loss: 1.7574 - val_accuracy: 0.4366
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7983 - accuracy: 0.7869
# Epoch 00004: val_loss improved from 1.75744 to 1.05601, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 176s 1s/step - loss: 0.7983 - accuracy: 0.7869 - val_loss: 1.0560 - val_accuracy: 0.6795
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.8330
# Epoch 00005: val_loss did not improve from 1.05601
# 140/140 [==============================] - 173s 1s/step - loss: 0.6525 - accuracy: 0.8330 - val_loss: 1.0858 - val_accuracy: 0.6319
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.5657 - accuracy: 0.8541
# Epoch 00006: val_loss improved from 1.05601 to 0.68772, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 173s 1s/step - loss: 0.5657 - accuracy: 0.8541 - val_loss: 0.6877 - val_accuracy: 0.7911
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4858 - accuracy: 0.8811
# Epoch 00007: val_loss improved from 0.68772 to 0.58919, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 172s 1s/step - loss: 0.4858 - accuracy: 0.8811 - val_loss: 0.5892 - val_accuracy: 0.8241
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4191 - accuracy: 0.8994
# Epoch 00008: val_loss improved from 0.58919 to 0.44878, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 178s 1s/step - loss: 0.4191 - accuracy: 0.8994 - val_loss: 0.4488 - val_accuracy: 0.8732
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.9072
# Epoch 00009: val_loss did not improve from 0.44878
# 140/140 [==============================] - 173s 1s/step - loss: 0.3834 - accuracy: 0.9072 - val_loss: 0.6917 - val_accuracy: 0.7960
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.9207
# Epoch 00010: val_loss improved from 0.44878 to 0.33518, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 174s 1s/step - loss: 0.3307 - accuracy: 0.9207 - val_loss: 0.3352 - val_accuracy: 0.9154
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.9287
# Epoch 00011: val_loss did not improve from 0.33518
# 140/140 [==============================] - 175s 1s/step - loss: 0.2982 - accuracy: 0.9287 - val_loss: 0.7742 - val_accuracy: 0.7569
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.9310
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00012: val_loss did not improve from 0.33518
# 140/140 [==============================] - 172s 1s/step - loss: 0.2804 - accuracy: 0.9310 - val_loss: 0.5260 - val_accuracy: 0.8446
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.9338
# Epoch 00013: val_loss improved from 0.33518 to 0.30518, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 173s 1s/step - loss: 0.2643 - accuracy: 0.9338 - val_loss: 0.3052 - val_accuracy: 0.9232
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.9439
# Epoch 00014: val_loss improved from 0.30518 to 0.26907, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 171s 1s/step - loss: 0.2368 - accuracy: 0.9439 - val_loss: 0.2691 - val_accuracy: 0.9359
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2101 - accuracy: 0.9505
# Epoch 00015: val_loss did not improve from 0.26907
# 140/140 [==============================] - 171s 1s/step - loss: 0.2101 - accuracy: 0.9505 - val_loss: 0.4765 - val_accuracy: 0.8498
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9441
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00016: val_loss did not improve from 0.26907
# 140/140 [==============================] - 172s 1s/step - loss: 0.2190 - accuracy: 0.9441 - val_loss: 0.4842 - val_accuracy: 0.8511
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9512Restoring model weights from the end of the best epoch.
#
# Epoch 00017: val_loss did not improve from 0.26907
# 140/140 [==============================] - 146s 1s/step - loss: 0.1989 - accuracy: 0.9512 - val_loss: 0.3199 - val_accuracy: 0.9002
# Epoch 00017: early stopping

# %% [markdown]
# ## Transfer learning on Pre-Trained Model (VGG-19)
#
# VGG-19 architecture is being used for this experienment.

# %%
conv_base = VGG19(weights="imagenet", 
                  include_top = False, # exclude the top three fully connected layer
                  input_shape = (INPUT_HEIGHT, INPUT_WIDTH, 3), # configure the input shape, default is 224*224*3
                 )

# %%
conv_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = conv_base.output

x = layers.Flatten()(x)

x = layers.Dropout(0.3)(x)

x = layers.Dense(256, activation='relu')(x)

predictions = layers.Dense(10, activation='softmax')(x)

# %%
t_model= models.Model(inputs=conv_base.input, outputs=predictions)

# %%
for layer in conv_base.layers:
    layer.trainable = False

#for layer in t_model.layers[:10]:
#    layer.trainable = False

# %%
#t_model.compile(loss='categorical_crossentropy', 
#                #optimizer='adam', 
#                optimizer=optimizers.Adam(lr=0.0001),
#                metrics=['accuracy'])

t_model.compile(loss='categorical_crossentropy', 
              #optimizer='adam', 
                optimizer=optimizers.Adam(lr=0.001),
              metrics=['accuracy'])

# %%
t_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 20,551,498
# Trainable params: 527,114
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(t_model, to_file="transfered_model_vgg19.png", show_shapes=True, show_layer_names=True)

# %%
t_model_path = MODEL_DIR + '/distracted_driver_detection_vgg19.h5'
model_cp = ModelCheckpoint(
    filepath=t_model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

callbacks = [model_cp, early_stop]

# %%
# reset data generator
train_generator.reset()
validation_generator.reset()

t_history=t_model.fit(train_generator, 
                      steps_per_epoch = TRAIN_STEPS, 
                      epochs = EPOCHES,
                      verbose = 1,
                      validation_data = validation_generator,
                      validation_steps = VALIDATION_STEPS,
                      callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 2.0945 - accuracy: 0.2438
# Epoch 00001: val_loss improved from inf to 1.86986, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 2.0945 - accuracy: 0.2438 - val_loss: 1.8699 - val_accuracy: 0.3379
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8633 - accuracy: 0.3329
# Epoch 00002: val_loss improved from 1.86986 to 1.72783, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 1.8633 - accuracy: 0.3329 - val_loss: 1.7278 - val_accuracy: 0.3743
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8029 - accuracy: 0.3555
# Epoch 00003: val_loss improved from 1.72783 to 1.68001, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 302s 2s/step - loss: 1.8029 - accuracy: 0.3555 - val_loss: 1.6800 - val_accuracy: 0.4100
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7433 - accuracy: 0.3805
# Epoch 00004: val_loss improved from 1.68001 to 1.61777, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 1.7433 - accuracy: 0.3805 - val_loss: 1.6178 - val_accuracy: 0.4337
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7018 - accuracy: 0.4000
# Epoch 00005: val_loss improved from 1.61777 to 1.56618, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 307s 2s/step - loss: 1.7018 - accuracy: 0.4000 - val_loss: 1.5662 - val_accuracy: 0.4437
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6799 - accuracy: 0.4052
# Epoch 00006: val_loss improved from 1.56618 to 1.54930, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 308s 2s/step - loss: 1.6799 - accuracy: 0.4052 - val_loss: 1.5493 - val_accuracy: 0.4574
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6721 - accuracy: 0.4036
# Epoch 00007: val_loss improved from 1.54930 to 1.51149, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.6721 - accuracy: 0.4036 - val_loss: 1.5115 - val_accuracy: 0.4801
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6247 - accuracy: 0.4216
# Epoch 00008: val_loss improved from 1.51149 to 1.48908, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.6247 - accuracy: 0.4216 - val_loss: 1.4891 - val_accuracy: 0.4775
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6196 - accuracy: 0.4236
# Epoch 00009: val_loss improved from 1.48908 to 1.47619, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 299s 2s/step - loss: 1.6196 - accuracy: 0.4236 - val_loss: 1.4762 - val_accuracy: 0.4862
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5984 - accuracy: 0.4329
# Epoch 00010: val_loss improved from 1.47619 to 1.47040, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 300s 2s/step - loss: 1.5984 - accuracy: 0.4329 - val_loss: 1.4704 - val_accuracy: 0.4839
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5960 - accuracy: 0.4342
# Epoch 00011: val_loss improved from 1.47040 to 1.42187, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 300s 2s/step - loss: 1.5960 - accuracy: 0.4342 - val_loss: 1.4219 - val_accuracy: 0.5116
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5654 - accuracy: 0.4452
# Epoch 00012: val_loss did not improve from 1.42187
# 140/140 [==============================] - 300s 2s/step - loss: 1.5654 - accuracy: 0.4452 - val_loss: 1.4308 - val_accuracy: 0.5089
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5593 - accuracy: 0.4469
# Epoch 00013: val_loss did not improve from 1.42187
# 140/140 [==============================] - 317s 2s/step - loss: 1.5593 - accuracy: 0.4469 - val_loss: 1.4312 - val_accuracy: 0.5080
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5384 - accuracy: 0.4582
# Epoch 00014: val_loss improved from 1.42187 to 1.40154, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 308s 2s/step - loss: 1.5384 - accuracy: 0.4582 - val_loss: 1.4015 - val_accuracy: 0.5158
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5314 - accuracy: 0.4637
# Epoch 00015: val_loss improved from 1.40154 to 1.36613, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 310s 2s/step - loss: 1.5314 - accuracy: 0.4637 - val_loss: 1.3661 - val_accuracy: 0.5275
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5103 - accuracy: 0.4615
# Epoch 00016: val_loss improved from 1.36613 to 1.34440, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 316s 2s/step - loss: 1.5103 - accuracy: 0.4615 - val_loss: 1.3444 - val_accuracy: 0.5417
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4862 - accuracy: 0.4749
# Epoch 00017: val_loss improved from 1.34440 to 1.34297, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 315s 2s/step - loss: 1.4862 - accuracy: 0.4749 - val_loss: 1.3430 - val_accuracy: 0.5382
# Epoch 18/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4951 - accuracy: 0.4684
# Epoch 00018: val_loss did not improve from 1.34297
# 140/140 [==============================] - 311s 2s/step - loss: 1.4951 - accuracy: 0.4684 - val_loss: 1.3461 - val_accuracy: 0.5304
# Epoch 19/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4680 - accuracy: 0.4808
# Epoch 00019: val_loss improved from 1.34297 to 1.31001, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 310s 2s/step - loss: 1.4680 - accuracy: 0.4808 - val_loss: 1.3100 - val_accuracy: 0.5449
# Epoch 20/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4621 - accuracy: 0.4860
# Epoch 00020: val_loss improved from 1.31001 to 1.30976, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 315s 2s/step - loss: 1.4621 - accuracy: 0.4860 - val_loss: 1.3098 - val_accuracy: 0.5600
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4363 - accuracy: 0.4913
# Epoch 00021: val_loss improved from 1.30976 to 1.30211, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 311s 2s/step - loss: 1.4363 - accuracy: 0.4913 - val_loss: 1.3021 - val_accuracy: 0.5683
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4268 - accuracy: 0.4959
# Epoch 00022: val_loss improved from 1.30211 to 1.27349, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 309s 2s/step - loss: 1.4268 - accuracy: 0.4959 - val_loss: 1.2735 - val_accuracy: 0.5683
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4094 - accuracy: 0.5027
# Epoch 00023: val_loss improved from 1.27349 to 1.26507, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.4094 - accuracy: 0.5027 - val_loss: 1.2651 - val_accuracy: 0.5654
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3977 - accuracy: 0.5009
# Epoch 00024: val_loss improved from 1.26507 to 1.25446, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 1.3977 - accuracy: 0.5009 - val_loss: 1.2545 - val_accuracy: 0.5683
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4037 - accuracy: 0.5036
# Epoch 00025: val_loss improved from 1.25446 to 1.24022, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 303s 2s/step - loss: 1.4037 - accuracy: 0.5036 - val_loss: 1.2402 - val_accuracy: 0.5866
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3817 - accuracy: 0.5113
# Epoch 00026: val_loss did not improve from 1.24022
# 140/140 [==============================] - 303s 2s/step - loss: 1.3817 - accuracy: 0.5113 - val_loss: 1.2480 - val_accuracy: 0.5685
# Epoch 27/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3769 - accuracy: 0.5163
# Epoch 00027: val_loss did not improve from 1.24022
# 140/140 [==============================] - 308s 2s/step - loss: 1.3769 - accuracy: 0.5163 - val_loss: 1.2509 - val_accuracy: 0.5737
# Epoch 28/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3647 - accuracy: 0.5193
# Epoch 00028: val_loss improved from 1.24022 to 1.21939, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 310s 2s/step - loss: 1.3647 - accuracy: 0.5193 - val_loss: 1.2194 - val_accuracy: 0.5853
# Epoch 29/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3593 - accuracy: 0.5197
# Epoch 00029: val_loss improved from 1.21939 to 1.20287, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 311s 2s/step - loss: 1.3593 - accuracy: 0.5197 - val_loss: 1.2029 - val_accuracy: 0.5924
# Epoch 30/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3494 - accuracy: 0.5259
# Epoch 00030: val_loss improved from 1.20287 to 1.17700, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 311s 2s/step - loss: 1.3494 - accuracy: 0.5259 - val_loss: 1.1770 - val_accuracy: 0.6027
# Epoch 31/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3483 - accuracy: 0.5226
# Epoch 00031: val_loss did not improve from 1.17700
# 140/140 [==============================] - 309s 2s/step - loss: 1.3483 - accuracy: 0.5226 - val_loss: 1.1824 - val_accuracy: 0.5951
# Epoch 32/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3418 - accuracy: 0.5264
# Epoch 00032: val_loss improved from 1.17700 to 1.17468, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 310s 2s/step - loss: 1.3418 - accuracy: 0.5264 - val_loss: 1.1747 - val_accuracy: 0.6080
# Epoch 33/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3366 - accuracy: 0.5297
# Epoch 00033: val_loss improved from 1.17468 to 1.16763, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 306s 2s/step - loss: 1.3366 - accuracy: 0.5297 - val_loss: 1.1676 - val_accuracy: 0.6107
# Epoch 34/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3358 - accuracy: 0.5322
# Epoch 00034: val_loss improved from 1.16763 to 1.14958, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 1.3358 - accuracy: 0.5322 - val_loss: 1.1496 - val_accuracy: 0.6071
# Epoch 35/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3025 - accuracy: 0.5456
# Epoch 00035: val_loss improved from 1.14958 to 1.14000, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 313s 2s/step - loss: 1.3025 - accuracy: 0.5456 - val_loss: 1.1400 - val_accuracy: 0.6154
# Epoch 36/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2997 - accuracy: 0.5431
# Epoch 00036: val_loss improved from 1.14000 to 1.12851, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 310s 2s/step - loss: 1.2997 - accuracy: 0.5431 - val_loss: 1.1285 - val_accuracy: 0.6183
# Epoch 37/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3020 - accuracy: 0.5413
# Epoch 00037: val_loss did not improve from 1.12851
# 140/140 [==============================] - 306s 2s/step - loss: 1.3020 - accuracy: 0.5413 - val_loss: 1.1356 - val_accuracy: 0.6176
# Epoch 38/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3019 - accuracy: 0.5400
# Epoch 00038: val_loss did not improve from 1.12851
# 140/140 [==============================] - 306s 2s/step - loss: 1.3019 - accuracy: 0.5400 - val_loss: 1.1456 - val_accuracy: 0.6203
# Epoch 39/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3033 - accuracy: 0.5369
# Epoch 00039: val_loss did not improve from 1.12851
# Restoring model weights from the end of the best epoch.
# 140/140 [==============================] - 300s 2s/step - loss: 1.3033 - accuracy: 0.5369 - val_loss: 1.1300 - val_accuracy: 0.6192
# Epoch 00039: early stopping

# %% [markdown]
# ## Performance Evalution
#
# Performance will be evaluated on losses and accuracy for trainning and validation. The function below is a generic function that can be used to plot either one based on user input.

# %%
def show_metric(history, metric):
    '''
    history: return value of the .fit, which includes all the history while training the model
    metric: which metric to plot
    '''
    train_metrics = history.history[metric]
    validation_metrics = history.history['val_' + metric]
    
    # make it start from 1
    train_epochs = range(1, len(train_metrics) + 1)
    
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
    plt.plot(train_epochs, train_metrics)
    plt.plot(train_epochs, validation_metrics)
    
    plt.title('Training and Validation '+ metric)
    
    plt.xlabel("Number of Epochs")
    plt.ylabel(metric)
    
    plt.legend(["Training " + metric, "Validation " + metric])
    plt.show()

    
def plot_confusion_matrix(data, labels):
    """Plot confusion matrix using heatmap.
 
    Args:
        data (list of list): List of lists with confusion matrix data.
        labels (list): Labels which will be plotted across x and y axis.
        output_filename (str): Path to output file.
 
    """
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
 
    plt.title("Confusion Matrix")
     
    ax = sns.heatmap(data, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
     
    plt.show()

# %% [markdown]
# #### Basic CNN Architecture

# %%
show_metric(history, "loss")
show_metric(history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8042 - accuracy: 0.7500
# Loss: 0.8042140007019043
# Accuracy: 0.75

# %%
test_generator.reset()
preds = model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c4       1.00      0.40      0.57        10
#           c2       0.77      1.00      0.87        10
#           c7       0.78      0.70      0.74        10
#           c8       0.90      0.90      0.90        10
#           c5       0.89      0.80      0.84        10
#           c1       0.91      1.00      0.95        10
#           c9       0.75      0.60      0.67        10
#           c6       1.00      0.90      0.95        10
#           c3       0.47      0.70      0.56        10
#           c0       0.42      0.50      0.45        10
#
#     accuracy                           0.75       100
#    macro avg       0.79      0.75      0.75       100
# weighted avg       0.79      0.75      0.75       100

# %% [markdown]
# ### Model with transfer learning on pre-trained model

# %%
show_metric(t_history, "loss")
show_metric(t_history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = t_model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6628 - accuracy: 0.4400
# Loss: 1.6628363132476807
# Accuracy: 0.4399999976158142

# %%
test_generator.reset()
preds = t_model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c4       0.56      0.50      0.53        10
#           c2       0.67      0.40      0.50        10
#           c7       0.38      0.50      0.43        10
#           c8       0.60      0.30      0.40        10
#           c5       0.42      0.50      0.45        10
#           c1       0.80      0.80      0.80        10
#           c9       0.33      0.10      0.15        10
#           c6       0.50      0.60      0.55        10
#           c3       0.60      0.30      0.40        10
#           c0       0.16      0.40      0.23        10
#
#     accuracy                           0.44       100
#    macro avg       0.50      0.44      0.44       100
# weighted avg       0.50      0.44      0.44       100

# %% [markdown]
# ## Model verification

# %%
def show_test_images(model):
    plt.subplots(figsize=(20, 6))
 
    for i in range(0, 10):              
        plt.subplot(2, 5, i+1)

        choosen_cls=random.choice(os.listdir(TEST_DIR))
        
        path = os.path.join(TEST_DIR, choosen_cls)
        
        choosen_file=random.choice(os.listdir(path))
        
        f_path = os.path.join(path, choosen_file)
        
        image = load_img(path=f_path, target_size=(INPUT_HEIGHT, INPUT_WIDTH))
        input_arr = img_to_array(image)
        input_arr = np.array([input_arr])  # Convert single image to a batch.
        predictions = model.predict(input_arr)
        
        predicted_class = 'c'+str(np.argmax(predictions))
        
        title_str = "Predicted: "+class_dict[predicted_class]
        
        image = mpimg.imread(f_path)
        
        plt.imshow(image)
        plt.title(title_str)
        plt.axis('off')

    plt.show()

# %%
# Load the model
base_model = models.load_model(model_path, compile=True)

show_test_images(base_model)

# %%
vgg19_model = models.load_model(t_model_path, compile = True)

show_test_images(vgg19_model)

# %% [markdown]
# ## Reference
#
# Image classification from scratch: https://keras.io/examples/vision/image_classification_from_scratch/
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# Building powerful image classification models using very little data: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
#
# Tutorial on using Keras flow_from_directory and generators: https://vijayabhaskar96.medium.com/tutorial-image-classification-with-keras-flow-from-directory-and-generators-95f75ebe5720
#
# Losses: https://keras.io/api/losses/
#
# How to use Callbacks in Keras to Visualize, Monitor and Improve your Deep Learning Model: https://medium.com/iitg-ai/how-to-use-callbacks-in-keras-to-visualize-monitor-and-improve-your-deep-learning-model-c9ca37901b28
#
# Image data preprocessing: https://keras.io/api/preprocessing/image/#image_dataset_from_directory-function
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# A Practical Introduction to Keras Callbacks in TensorFlow 2: https://towardsdatascience.com/a-practical-introduction-to-keras-callbacks-in-tensorflow-2-705d0c584966
#
# 4 Pre-Trained CNN Models to Use for Computer Vision with Transfer Learning: https://towardsdatascience.com/4-pre-trained-cnn-models-to-use-for-computer-vision-with-transfer-learning-885cb1b2dfc
#
# Keras Applications: https://keras.io/api/applications/
#
#  A simple example: Confusion Matrix with Keras flow_from_directory.py: https://gist.github.com/RyanAkilos/3808c17f79e77c4117de35aa68447045#file-a-simple-example-confusion-matrix-with-keras-flow_from_directory-py
