# %% [markdown]
# # *Distracted Driver Detection with CNN - Base*
#
# **The objectives of this project are the following:**
# - Implement and train an basic CNN model for distracted driver detection
# - Train a model based on a pre-trained model(VGG-19) via transfer learning
# - Evaluate the performance of both models for their loss and accuracy, including training and validation.
# - Load trained models and use it to run classification on test data that the model never seen before.

# %% [markdown]
# ## Libaries
#
# The main software application being used for this project is *Keras*, including data pre-processing, architecture, model training, training callback functions, and model metrics. *matplotlib* and *seaborn* is also imported for plotting; *os* and *glob* are used for locating and accessing files, etc.

# %%
from keras import layers # layers
from keras import models # models
from keras import optimizers # optimizers for complilation 
from keras import losses # losses 
from keras import metrics # metrics
from keras.utils import plot_model # show the model details in graph

### Callback functions ### 
from keras.callbacks import EarlyStopping  # stop earlier
from keras.callbacks import ReduceLROnPlateau # update the learning rate
from keras.callbacks import ModelCheckpoint # save model,weights

from keras.preprocessing.image import ImageDataGenerator # read images and augumentation
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array
from keras.applications import VGG19
from keras.applications import MobileNet

from PIL import Image
from glob import glob

import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import random

# %%
# check the version of keras
import keras
print(keras.__version__)
# Out:
# 2.4.3

# %%
# do i have a GPU available ??? 
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## Dataset
#
# The dataset was found from *kaggle* at: [https://www.kaggle.com/c/state-farm-distracted-driver-detection/data], which includes labeled driver images; each class is an behavior that was classified, such as, texting, eating, talking on the phone, makeup, reaching behind, etc. It also provides test data that are not labeled, all can be found within same folder.
#
# The 10 classes to predict are:
#
# - c0: safe driving
# - c1: texting - right
# - c2: talking on the phone - right
# - c3: texting - left
# - c4: talking on the phone - left
# - c5: operating the radio
# - c6: drinking
# - c7: reaching behind
# - c8: hair and makeup
# - c9: talking to passenger

# %% [markdown]
# ### Descriptions
#
# The downloaded dataset is a compressed zip package, it includes three part after unzip.
#
# - imgs: driver pictures will be used, and including train and test as sub-folders.
# - driver_imgs_list.csv - csv file that includes the name of driver picturs, subject id(driver), class id(class).
# - sample_submission.csv - sample submission file since this is a kaggle competition. (**I WILL NOT USE THIS FILE**)

# %%
CURR_DIR = os.getcwd()

DATA_DIR = os.path.join(CURR_DIR, "data/state-farm-distracted-driver-detection/")

TRAIN_DIR = os.path.join(DATA_DIR, "imgs/train")  # train dir has sub-classes folders 
TEST_DIR = os.path.join(DATA_DIR, "imgs/test")    # test data folder

DATA_FILE = os.path.join(DATA_DIR, "driver_imgs_list.csv") # train images and according class and driver

# ensure the folder exist for saving the models
MODEL_DIR = os.path.join(CURR_DIR, "saved_models")

# create the model dir if not exist
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# define the class and its according description 

# classes 
classes = {'c0','c1','c2','c3','c4','c5','c6','c7','c8','c9'}

# {folder name}:{description}
class_dict = {'c0': 'Safe driving', 
              'c1': 'Texting - right', 
              'c2': 'Talking on the phone - right', 
              'c3': 'Texting - left', 
              'c4': 'Talking on the phone - left', 
              'c5': 'Operating the radio', 
              'c6': 'Drinking', 
              'c7': 'Reaching behind', 
              'c8': 'Hair and makeup', 
              'c9': 'Talking to passenger'}

# %% [markdown]
# #### Parameters setup
#
# Before data pre-processing, I will define the input shape(target height and width), and number of training epochs, and the batch size that helps to reduce the memory usage when running on less powerful platforms.

# %%
#INPUT_WIDTH = 32
#INPUT_HEIGHT = 32

INPUT_WIDTH = 64
INPUT_HEIGHT = 64

# %%
#EPOCHES = 5
#SIZE = 32

EPOCHES = 50
BATCH_SIZE = 128

# %% [markdown]
# #### Data Pre-Processing
#
# With *Keras*, image data processing has become much easier. Instead of reading subfolers for all files, load pictures and covert to numpy array, *Keras* provides API calls, *flow_from_directory*, which will read data from specified directory and categorize to different classes, load with resizing, etc, with the usage of *ImageDataGenerator*.

# %%
# with data augmentation 
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   brightness_range=[0.4, 1.2],
                                   shear_range=0.2,
                                   zoom_range=0.3,
                                   validation_split=0.2)

train_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                    target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                    classes=None, 
                                                    class_mode='categorical',
                                                    batch_size=BATCH_SIZE, 
                                                    shuffle=True, 
                                                    subset='training')

validation_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                         target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                         classes=None, 
                                                         class_mode='categorical',
                                                         batch_size=BATCH_SIZE, 
                                                         shuffle=True, 
                                                         subset='validation')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(TEST_DIR, 
                                                  target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=False, 
                                                  class_mode='categorical')
# Out:
# Found 17943 images belonging to 10 classes.
# Found 4481 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
# calculate the steps for training and validation
TRAIN_STEPS = train_generator.samples // BATCH_SIZE
VALIDATION_STEPS = validation_generator.samples // BATCH_SIZE

# %% [markdown]
# ## Basic CNN Architeture

# %%
model = models.Sequential()

# filters, stride, input size, chanel 
model.add(layers.Conv2D(32, (5,5), padding='same', input_shape=(INPUT_HEIGHT, INPUT_WIDTH, 3)))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(32) * height * width 

model.add(layers.Conv2D(64, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(64) * height/2 * width/2 

model.add(layers.Conv2D(128, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(128) * height/4 * width/4 

model.add(layers.Flatten())

model.add(layers.Dropout(0.3))

model.add(layers.Dense(256))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.Dense(10))

model.add(layers.BatchNormalization())

model.add(layers.Activation("softmax"))

# %%
# use categorical crossentropy since our data is multi-class classification
#loss_func = losses.CategoricalCrossentropy(from_logits=False, name="categorical_crossentropy")

# outperforms others in practice, RMSprop + Momentum
#opt_func = optimizers.Adam(lr=0.0001)

model.compile(loss='categorical_crossentropy', 
              #optimizer='adam', 
              optimizer=optimizers.Adam(lr=0.0001),
              metrics=['accuracy'])

#model.compile(loss=loss_func, 
#              optimizer=opt_func, 
#              metrics=['accuracy'])

# %%
# check the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10)                40
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 2,360,562
# Trainable params: 2,359,582
# Non-trainable params: 980
# _________________________________________________________________

# %%
# plot the model in picture format to visualize how layers are connected with according input/output size
plot_model(model, to_file="basic_cnn_model.png", show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Callback functions
#
# Callback functions are provided by *Keras*, which will be executed during the training of the model and can be used for different purposes; In this project, I will use the following three callback APIS:
# - EarlyStopping: stop the training earlier if the specified metric stopped improving
# - ReduceLROnPlateau: adjust the learning rate when the specified metric stopped improving
# - ModelCheckpoint: save the model weights and model each training epoch

# %%
# define callback functions
# 1: early stopping 
# https://keras.io/api/callbacks/early_stopping/
early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

# 2: reduce the learning rate when a metric has stopped improving 
# https://keras.io/api/callbacks/reduce_lr_on_plateau/
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # monitored metric
    factor=0.2,   # new lr = factor * lr
    patience=2,   # number of epochs 
    min_lr=0.001,  # min lr
    verbose=1
)

# 3: save model or model weights
# https://keras.io/api/callbacks/model_checkpoint/
model_path = MODEL_DIR + '/distracted_driver_detection_base.h5'
model_cp = ModelCheckpoint(
    filepath=model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, model_cp]
#callbacks = []

# %%
history=model.fit(train_generator, 
                  steps_per_epoch = TRAIN_STEPS, 
                  epochs = EPOCHES,
                  verbose = 1,
                  validation_data = validation_generator,
                  validation_steps = VALIDATION_STEPS,
                  callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 2.2326 - accuracy: 0.1897
# Epoch 00001: val_loss improved from inf to 2.31130, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 174s 1s/step - loss: 2.2326 - accuracy: 0.1897 - val_loss: 2.3113 - val_accuracy: 0.0944
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 1.9573 - accuracy: 0.2947
# Epoch 00002: val_loss improved from 2.31130 to 2.24071, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 165s 1s/step - loss: 1.9573 - accuracy: 0.2947 - val_loss: 2.2407 - val_accuracy: 0.1739
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7372 - accuracy: 0.3901
# Epoch 00003: val_loss improved from 2.24071 to 1.94812, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 165s 1s/step - loss: 1.7372 - accuracy: 0.3901 - val_loss: 1.9481 - val_accuracy: 0.3129
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5747 - accuracy: 0.4675
# Epoch 00004: val_loss improved from 1.94812 to 1.79240, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 166s 1s/step - loss: 1.5747 - accuracy: 0.4675 - val_loss: 1.7924 - val_accuracy: 0.3848
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4454 - accuracy: 0.5333
# Epoch 00005: val_loss improved from 1.79240 to 1.42201, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 163s 1s/step - loss: 1.4454 - accuracy: 0.5333 - val_loss: 1.4220 - val_accuracy: 0.5688
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3448 - accuracy: 0.5874
# Epoch 00006: val_loss improved from 1.42201 to 1.32685, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 164s 1s/step - loss: 1.3448 - accuracy: 0.5874 - val_loss: 1.3269 - val_accuracy: 0.5962
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 1.2532 - accuracy: 0.6267
# Epoch 00007: val_loss improved from 1.32685 to 1.16788, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 165s 1s/step - loss: 1.2532 - accuracy: 0.6267 - val_loss: 1.1679 - val_accuracy: 0.6748
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 1.1812 - accuracy: 0.6668
# Epoch 00008: val_loss improved from 1.16788 to 1.14041, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 164s 1s/step - loss: 1.1812 - accuracy: 0.6668 - val_loss: 1.1404 - val_accuracy: 0.6556
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 1.1101 - accuracy: 0.7006
# Epoch 00009: val_loss improved from 1.14041 to 1.01520, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 165s 1s/step - loss: 1.1101 - accuracy: 0.7006 - val_loss: 1.0152 - val_accuracy: 0.7518
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 1.0550 - accuracy: 0.7251
# Epoch 00010: val_loss did not improve from 1.01520
# 140/140 [==============================] - 165s 1s/step - loss: 1.0550 - accuracy: 0.7251 - val_loss: 1.0361 - val_accuracy: 0.7225
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 1.0035 - accuracy: 0.7466
# Epoch 00011: val_loss improved from 1.01520 to 0.96401, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 168s 1s/step - loss: 1.0035 - accuracy: 0.7466 - val_loss: 0.9640 - val_accuracy: 0.7645
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 0.9613 - accuracy: 0.7644
# Epoch 00012: val_loss improved from 0.96401 to 0.88905, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 170s 1s/step - loss: 0.9613 - accuracy: 0.7644 - val_loss: 0.8891 - val_accuracy: 0.8065
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 0.9260 - accuracy: 0.7790
# Epoch 00013: val_loss improved from 0.88905 to 0.86063, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 173s 1s/step - loss: 0.9260 - accuracy: 0.7790 - val_loss: 0.8606 - val_accuracy: 0.8065
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 0.8827 - accuracy: 0.7940
# Epoch 00014: val_loss improved from 0.86063 to 0.80024, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 175s 1s/step - loss: 0.8827 - accuracy: 0.7940 - val_loss: 0.8002 - val_accuracy: 0.8344
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 0.8415 - accuracy: 0.8074
# Epoch 00015: val_loss did not improve from 0.80024
# 140/140 [==============================] - 174s 1s/step - loss: 0.8415 - accuracy: 0.8074 - val_loss: 0.8131 - val_accuracy: 0.8040
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 0.8152 - accuracy: 0.8173
# Epoch 00016: val_loss improved from 0.80024 to 0.78745, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 174s 1s/step - loss: 0.8152 - accuracy: 0.8173 - val_loss: 0.7875 - val_accuracy: 0.8167
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7818 - accuracy: 0.8323
# Epoch 00017: val_loss improved from 0.78745 to 0.71336, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 182s 1s/step - loss: 0.7818 - accuracy: 0.8323 - val_loss: 0.7134 - val_accuracy: 0.8480
# Epoch 18/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7614 - accuracy: 0.8366
# Epoch 00018: val_loss improved from 0.71336 to 0.67322, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 175s 1s/step - loss: 0.7614 - accuracy: 0.8366 - val_loss: 0.6732 - val_accuracy: 0.8687
# Epoch 19/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7309 - accuracy: 0.8465
# Epoch 00019: val_loss did not improve from 0.67322
# 140/140 [==============================] - 169s 1s/step - loss: 0.7309 - accuracy: 0.8465 - val_loss: 0.6884 - val_accuracy: 0.8531
# Epoch 20/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7074 - accuracy: 0.8522
# Epoch 00020: val_loss did not improve from 0.67322
# 140/140 [==============================] - 170s 1s/step - loss: 0.7074 - accuracy: 0.8522 - val_loss: 0.6799 - val_accuracy: 0.8507
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6900 - accuracy: 0.8573
# Epoch 00021: val_loss improved from 0.67322 to 0.62861, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 170s 1s/step - loss: 0.6900 - accuracy: 0.8573 - val_loss: 0.6286 - val_accuracy: 0.8804
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6618 - accuracy: 0.8681
# Epoch 00022: val_loss improved from 0.62861 to 0.61695, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 175s 1s/step - loss: 0.6618 - accuracy: 0.8681 - val_loss: 0.6170 - val_accuracy: 0.8917
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6487 - accuracy: 0.8710
# Epoch 00023: val_loss improved from 0.61695 to 0.54733, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 172s 1s/step - loss: 0.6487 - accuracy: 0.8710 - val_loss: 0.5473 - val_accuracy: 0.9103
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6234 - accuracy: 0.8775
# Epoch 00024: val_loss did not improve from 0.54733
# 140/140 [==============================] - 171s 1s/step - loss: 0.6234 - accuracy: 0.8775 - val_loss: 0.5768 - val_accuracy: 0.8842
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6105 - accuracy: 0.8788
# Epoch 00025: val_loss did not improve from 0.54733
# 140/140 [==============================] - 172s 1s/step - loss: 0.6105 - accuracy: 0.8788 - val_loss: 0.5575 - val_accuracy: 0.8833
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 0.5901 - accuracy: 0.8865Restoring model weights from the end of the best epoch.
#
# Epoch 00026: val_loss did not improve from 0.54733
# 140/140 [==============================] - 179s 1s/step - loss: 0.5901 - accuracy: 0.8865 - val_loss: 0.5500 - val_accuracy: 0.8949
# Epoch 00026: early stopping

# %% [markdown]
# ## Transfer learning on Pre-Trained Model (VGG-19)
#
# VGG-19 architecture is being used for this experienment.

# %%
conv_base = VGG19(weights="imagenet", 
                  include_top = False, # exclude the top three fully connected layer
                  input_shape = (INPUT_HEIGHT, INPUT_WIDTH, 3), # configure the input shape, default is 224*224*3
                 )

# %%
conv_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = conv_base.output

x = layers.Flatten()(x)

x = layers.Dropout(0.3)(x)

x = layers.Dense(256, activation='relu')(x)

predictions = layers.Dense(10, activation='softmax')(x)

# %%
t_model= models.Model(inputs=conv_base.input, outputs=predictions)

# %%
for layer in conv_base.layers:
    layer.trainable = False

#for layer in t_model.layers[:10]:
#    layer.trainable = False

# %%
#t_model.compile(loss='categorical_crossentropy', 
#                #optimizer='adam', 
#                optimizer=optimizers.Adam(lr=0.0001),
#                metrics=['accuracy'])

t_model.compile(loss='categorical_crossentropy', 
              #optimizer='adam', 
                optimizer=optimizers.Adam(lr=0.0001),
              metrics=['accuracy'])

# %%
t_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 20,551,498
# Trainable params: 527,114
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(t_model, to_file="transfered_model_vgg19.png", show_shapes=True, show_layer_names=True)

# %%
t_model_path = MODEL_DIR + '/distracted_driver_detection_vgg19.h5'
model_cp = ModelCheckpoint(
    filepath=t_model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

callbacks = [model_cp, early_stop]

# %%
# reset data generator
train_generator.reset()
validation_generator.reset()

t_history=t_model.fit(train_generator, 
                      steps_per_epoch = TRAIN_STEPS, 
                      epochs = EPOCHES,
                      verbose = 1,
                      validation_data = validation_generator,
                      validation_steps = VALIDATION_STEPS,
                      callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 2.3342 - accuracy: 0.1455
# Epoch 00001: val_loss improved from inf to 2.15089, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 299s 2s/step - loss: 2.3342 - accuracy: 0.1455 - val_loss: 2.1509 - val_accuracy: 0.2277
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 2.1320 - accuracy: 0.2216
# Epoch 00002: val_loss improved from 2.15089 to 2.02445, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 304s 2s/step - loss: 2.1320 - accuracy: 0.2216 - val_loss: 2.0245 - val_accuracy: 0.2859
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 2.0371 - accuracy: 0.2652
# Epoch 00003: val_loss improved from 2.02445 to 1.94762, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 2.0371 - accuracy: 0.2652 - val_loss: 1.9476 - val_accuracy: 0.3127
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 1.9760 - accuracy: 0.2858
# Epoch 00004: val_loss improved from 1.94762 to 1.87890, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 299s 2s/step - loss: 1.9760 - accuracy: 0.2858 - val_loss: 1.8789 - val_accuracy: 0.3339
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 1.9162 - accuracy: 0.3131
# Epoch 00005: val_loss improved from 1.87890 to 1.83170, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 299s 2s/step - loss: 1.9162 - accuracy: 0.3131 - val_loss: 1.8317 - val_accuracy: 0.3509
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8800 - accuracy: 0.3285
# Epoch 00006: val_loss improved from 1.83170 to 1.78274, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.8800 - accuracy: 0.3285 - val_loss: 1.7827 - val_accuracy: 0.3786
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8415 - accuracy: 0.3411
# Epoch 00007: val_loss improved from 1.78274 to 1.77441, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 1.8415 - accuracy: 0.3411 - val_loss: 1.7744 - val_accuracy: 0.3768
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8197 - accuracy: 0.3548
# Epoch 00008: val_loss improved from 1.77441 to 1.73487, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 295s 2s/step - loss: 1.8197 - accuracy: 0.3548 - val_loss: 1.7349 - val_accuracy: 0.3951
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7863 - accuracy: 0.3627
# Epoch 00009: val_loss improved from 1.73487 to 1.70686, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 296s 2s/step - loss: 1.7863 - accuracy: 0.3627 - val_loss: 1.7069 - val_accuracy: 0.4123
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7786 - accuracy: 0.3702
# Epoch 00010: val_loss improved from 1.70686 to 1.67653, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 296s 2s/step - loss: 1.7786 - accuracy: 0.3702 - val_loss: 1.6765 - val_accuracy: 0.4225
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7563 - accuracy: 0.3774
# Epoch 00011: val_loss improved from 1.67653 to 1.65580, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 296s 2s/step - loss: 1.7563 - accuracy: 0.3774 - val_loss: 1.6558 - val_accuracy: 0.4359
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7382 - accuracy: 0.3823
# Epoch 00012: val_loss improved from 1.65580 to 1.64386, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 300s 2s/step - loss: 1.7382 - accuracy: 0.3823 - val_loss: 1.6439 - val_accuracy: 0.4324
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7254 - accuracy: 0.3926
# Epoch 00013: val_loss did not improve from 1.64386
# 140/140 [==============================] - 298s 2s/step - loss: 1.7254 - accuracy: 0.3926 - val_loss: 1.6488 - val_accuracy: 0.4290
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7181 - accuracy: 0.3919
# Epoch 00014: val_loss improved from 1.64386 to 1.63291, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 301s 2s/step - loss: 1.7181 - accuracy: 0.3919 - val_loss: 1.6329 - val_accuracy: 0.4366
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7122 - accuracy: 0.3955
# Epoch 00015: val_loss improved from 1.63291 to 1.60477, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 1.7122 - accuracy: 0.3955 - val_loss: 1.6048 - val_accuracy: 0.4511
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7002 - accuracy: 0.3999
# Epoch 00016: val_loss did not improve from 1.60477
# 140/140 [==============================] - 295s 2s/step - loss: 1.7002 - accuracy: 0.3999 - val_loss: 1.6218 - val_accuracy: 0.4433
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6878 - accuracy: 0.4001
# Epoch 00017: val_loss improved from 1.60477 to 1.56116, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 294s 2s/step - loss: 1.6878 - accuracy: 0.4001 - val_loss: 1.5612 - val_accuracy: 0.4609
# Epoch 18/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6839 - accuracy: 0.4041
# Epoch 00018: val_loss did not improve from 1.56116
# 140/140 [==============================] - 296s 2s/step - loss: 1.6839 - accuracy: 0.4041 - val_loss: 1.5772 - val_accuracy: 0.4491
# Epoch 19/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6739 - accuracy: 0.4135
# Epoch 00019: val_loss did not improve from 1.56116
# 140/140 [==============================] - 297s 2s/step - loss: 1.6739 - accuracy: 0.4135 - val_loss: 1.5708 - val_accuracy: 0.4576
# Epoch 20/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6683 - accuracy: 0.4135
# Epoch 00020: val_loss improved from 1.56116 to 1.55838, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.6683 - accuracy: 0.4135 - val_loss: 1.5584 - val_accuracy: 0.4719
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6508 - accuracy: 0.4212
# Epoch 00021: val_loss did not improve from 1.55838
# 140/140 [==============================] - 295s 2s/step - loss: 1.6508 - accuracy: 0.4212 - val_loss: 1.5763 - val_accuracy: 0.4540
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6542 - accuracy: 0.4204
# Epoch 00022: val_loss improved from 1.55838 to 1.52746, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.6542 - accuracy: 0.4204 - val_loss: 1.5275 - val_accuracy: 0.4806
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6452 - accuracy: 0.4204
# Epoch 00023: val_loss did not improve from 1.52746
# 140/140 [==============================] - 297s 2s/step - loss: 1.6452 - accuracy: 0.4204 - val_loss: 1.5536 - val_accuracy: 0.4614
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6479 - accuracy: 0.4221
# Epoch 00024: val_loss did not improve from 1.52746
# 140/140 [==============================] - 299s 2s/step - loss: 1.6479 - accuracy: 0.4221 - val_loss: 1.5355 - val_accuracy: 0.4763
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6433 - accuracy: 0.4208
# Epoch 00025: val_loss improved from 1.52746 to 1.51489, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 296s 2s/step - loss: 1.6433 - accuracy: 0.4208 - val_loss: 1.5149 - val_accuracy: 0.4859
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6290 - accuracy: 0.4253
# Epoch 00026: val_loss improved from 1.51489 to 1.51203, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 293s 2s/step - loss: 1.6290 - accuracy: 0.4253 - val_loss: 1.5120 - val_accuracy: 0.4922
# Epoch 27/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6337 - accuracy: 0.4284
# Epoch 00027: val_loss did not improve from 1.51203
# 140/140 [==============================] - 295s 2s/step - loss: 1.6337 - accuracy: 0.4284 - val_loss: 1.5364 - val_accuracy: 0.4801
# Epoch 28/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6265 - accuracy: 0.4268
# Epoch 00028: val_loss did not improve from 1.51203
# 140/140 [==============================] - 300s 2s/step - loss: 1.6265 - accuracy: 0.4268 - val_loss: 1.5253 - val_accuracy: 0.4866
# Epoch 29/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6135 - accuracy: 0.4354
# Epoch 00029: val_loss did not improve from 1.51203
# Restoring model weights from the end of the best epoch.
# 140/140 [==============================] - 298s 2s/step - loss: 1.6135 - accuracy: 0.4354 - val_loss: 1.5143 - val_accuracy: 0.4792
# Epoch 00029: early stopping

# %% [markdown]
# ## Performance Evalution
#
# Performance will be evaluated on losses and accuracy for trainning and validation. The function below is a generic function that can be used to plot either one based on user input.

# %%
def show_metric(history, metric):
    '''
    history: return value of the .fit, which includes all the history while training the model
    metric: which metric to plot
    '''
    train_metrics = history.history[metric]
    validation_metrics = history.history['val_' + metric]
    
    # make it start from 1
    train_epochs = range(1, len(train_metrics) + 1)
    
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
    plt.plot(train_epochs, train_metrics)
    plt.plot(train_epochs, validation_metrics)
    
    plt.title('Training and Validation '+ metric)
    
    plt.xlabel("Number of Epochs")
    plt.ylabel(metric)
    
    plt.legend(["Training " + metric, "Validation " + metric])
    plt.show()

    
def plot_confusion_matrix(data, labels):
    """Plot confusion matrix using heatmap.
 
    Args:
        data (list of list): List of lists with confusion matrix data.
        labels (list): Labels which will be plotted across x and y axis.
        output_filename (str): Path to output file.
 
    """
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
 
    plt.title("Confusion Matrix")
     
    ax = sns.heatmap(data, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
     
    plt.show()

# %% [markdown]
# #### Basic CNN Architecture

# %%
show_metric(history, "loss")
show_metric(history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9609 - accuracy: 0.7000
# Loss: 0.9609302282333374
# Accuracy: 0.699999988079071

# %%
test_generator.reset()
preds = model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c3       0.71      0.50      0.59        10
#           c5       0.69      0.90      0.78        10
#           c2       0.75      0.60      0.67        10
#           c6       0.80      0.80      0.80        10
#           c0       0.89      0.80      0.84        10
#           c1       0.71      1.00      0.83        10
#           c7       1.00      0.50      0.67        10
#           c8       0.88      0.70      0.78        10
#           c4       0.83      0.50      0.62        10
#           c9       0.35      0.70      0.47        10
#
#     accuracy                           0.70       100
#    macro avg       0.76      0.70      0.70       100
# weighted avg       0.76      0.70      0.70       100

# %% [markdown]
# ### Model with transfer learning on pre-trained model

# %%
show_metric(t_history, "loss")
show_metric(t_history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = t_model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4672 - accuracy: 0.4700
# Loss: 1.467170000076294
# Accuracy: 0.4699999988079071

# %%
test_generator.reset()
preds = t_model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c3       0.50      0.30      0.37        10
#           c5       0.55      0.60      0.57        10
#           c2       0.42      0.50      0.45        10
#           c6       0.50      0.30      0.37        10
#           c0       0.31      0.50      0.38        10
#           c1       0.88      0.70      0.78        10
#           c7       0.50      0.40      0.44        10
#           c8       0.75      0.60      0.67        10
#           c4       0.29      0.40      0.33        10
#           c9       0.36      0.40      0.38        10
#
#     accuracy                           0.47       100
#    macro avg       0.50      0.47      0.48       100
# weighted avg       0.50      0.47      0.48       100

# %% [markdown]
# ## Model verification

# %%
def show_test_images(model):
    plt.subplots(figsize=(20, 6))
 
    for i in range(0, 10):              
        plt.subplot(2, 5, i+1)

        choosen_cls=random.choice(os.listdir(TEST_DIR))
        
        path = os.path.join(TEST_DIR, choosen_cls)
        
        choosen_file=random.choice(os.listdir(path))
        
        f_path = os.path.join(path, choosen_file)
        
        image = load_img(path=f_path, target_size=(INPUT_HEIGHT, INPUT_WIDTH))
        input_arr = img_to_array(image)
        input_arr = np.array([input_arr])  # Convert single image to a batch.
        predictions = model.predict(input_arr)
        
        predicted_class = 'c'+str(np.argmax(predictions))
        
        title_str = "Predicted: "+class_dict[predicted_class]
        
        image = mpimg.imread(f_path)
        
        plt.imshow(image)
        plt.title(title_str)
        plt.axis('off')

    plt.show()

# %%
# Load the model
base_model = models.load_model(model_path, compile=True)

show_test_images(base_model)

# %%
vgg19_model = models.load_model(t_model_path, compile = True)

show_test_images(vgg19_model)

# %% [markdown]
# ## Reference
#
# Image classification from scratch: https://keras.io/examples/vision/image_classification_from_scratch/
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# Building powerful image classification models using very little data: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
#
# Tutorial on using Keras flow_from_directory and generators: https://vijayabhaskar96.medium.com/tutorial-image-classification-with-keras-flow-from-directory-and-generators-95f75ebe5720
#
# Losses: https://keras.io/api/losses/
#
# How to use Callbacks in Keras to Visualize, Monitor and Improve your Deep Learning Model: https://medium.com/iitg-ai/how-to-use-callbacks-in-keras-to-visualize-monitor-and-improve-your-deep-learning-model-c9ca37901b28
#
# Image data preprocessing: https://keras.io/api/preprocessing/image/#image_dataset_from_directory-function
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# A Practical Introduction to Keras Callbacks in TensorFlow 2: https://towardsdatascience.com/a-practical-introduction-to-keras-callbacks-in-tensorflow-2-705d0c584966
#
# 4 Pre-Trained CNN Models to Use for Computer Vision with Transfer Learning: https://towardsdatascience.com/4-pre-trained-cnn-models-to-use-for-computer-vision-with-transfer-learning-885cb1b2dfc
#
# Keras Applications: https://keras.io/api/applications/
#
#  A simple example: Confusion Matrix with Keras flow_from_directory.py: https://gist.github.com/RyanAkilos/3808c17f79e77c4117de35aa68447045#file-a-simple-example-confusion-matrix-with-keras-flow_from_directory-py
