# %% [markdown]
# # *Distracted Driver Detection with CNN - Base*
#
# **The objectives of this project are the following:**
# - Implement and train an basic CNN model for distracted driver detection
# - Train a model based on a pre-trained model(VGG-19) via transfer learning
# - Evaluate the performance of both models for their loss and accuracy, including training and validation.
# - Load trained models and use it to run classification on test data that the model never seen before.

# %% [markdown]
# ## Libaries
#
# The main software application being used for this project is *Keras*, including data pre-processing, architecture, model training, training callback functions, and model metrics. *matplotlib* and *seaborn* is also imported for plotting; *os* and *glob* are used for locating and accessing files, etc.

# %%
from keras import layers # layers
from keras import models # models
from keras import optimizers # optimizers for complilation 
from keras import losses # losses 
from keras import metrics # metrics
from keras.utils import plot_model # show the model details in graph

### Callback functions ### 
from keras.callbacks import EarlyStopping  # stop earlier
from keras.callbacks import ReduceLROnPlateau # update the learning rate
from keras.callbacks import ModelCheckpoint # save model,weights

from keras.preprocessing.image import ImageDataGenerator # read images and augumentation
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array
from keras.applications import VGG19
from keras.applications import MobileNet

from PIL import Image
from glob import glob

import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import random

# %%
# check the version of keras
import keras
print(keras.__version__)
# Out:
# 2.4.3

# %%
# do i have a GPU available ??? 
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## Dataset
#
# The dataset was found from *kaggle* at: [https://www.kaggle.com/c/state-farm-distracted-driver-detection/data], which includes labeled driver images; each class is an behavior that was classified, such as, texting, eating, talking on the phone, makeup, reaching behind, etc. It also provides test data that are not labeled, all can be found within same folder.
#
# The 10 classes to predict are:
#
# - c0: safe driving
# - c1: texting - right
# - c2: talking on the phone - right
# - c3: texting - left
# - c4: talking on the phone - left
# - c5: operating the radio
# - c6: drinking
# - c7: reaching behind
# - c8: hair and makeup
# - c9: talking to passenger

# %% [markdown]
# ### Descriptions
#
# The downloaded dataset is a compressed zip package, it includes three part after unzip.
#
# - imgs: driver pictures will be used, and including train and test as sub-folders.
# - driver_imgs_list.csv - csv file that includes the name of driver picturs, subject id(driver), class id(class).
# - sample_submission.csv - sample submission file since this is a kaggle competition. (**I WILL NOT USE THIS FILE**)

# %%
CURR_DIR = os.getcwd()

DATA_DIR = os.path.join(CURR_DIR, "data/state-farm-distracted-driver-detection/")

TRAIN_DIR = os.path.join(DATA_DIR, "imgs/train")  # train dir has sub-classes folders 
TEST_DIR = os.path.join(DATA_DIR, "imgs/test")    # test data folder

DATA_FILE = os.path.join(DATA_DIR, "driver_imgs_list.csv") # train images and according class and driver

# ensure the folder exist for saving the models
MODEL_DIR = os.path.join(CURR_DIR, "saved_models")

# create the model dir if not exist
if not os.path.exists(MODEL_DIR):
    os.makedirs(MODEL_DIR)

# %%
# define the class and its according description 

# classes 
classes = {'c0','c1','c2','c3','c4','c5','c6','c7','c8','c9'}

# {folder name}:{description}
class_dict = {'c0': 'Safe driving', 
              'c1': 'Texting - right', 
              'c2': 'Talking on the phone - right', 
              'c3': 'Texting - left', 
              'c4': 'Talking on the phone - left', 
              'c5': 'Operating the radio', 
              'c6': 'Drinking', 
              'c7': 'Reaching behind', 
              'c8': 'Hair and makeup', 
              'c9': 'Talking to passenger'}

# %% [markdown]
# #### Parameters setup
#
# Before data pre-processing, I will define the input shape(target height and width), and number of training epochs, and the batch size that helps to reduce the memory usage when running on less powerful platforms.

# %%
#INPUT_WIDTH = 32
#INPUT_HEIGHT = 32

INPUT_WIDTH = 64
INPUT_HEIGHT = 64

# %%
#EPOCHES = 5
#SIZE = 32

EPOCHES = 50
BATCH_SIZE = 128

# %% [markdown]
# #### Data Pre-Processing
#
# With *Keras*, image data processing has become much easier. Instead of reading subfolers for all files, load pictures and covert to numpy array, *Keras* provides API calls, *flow_from_directory*, which will read data from specified directory and categorize to different classes, load with resizing, etc, with the usage of *ImageDataGenerator*.

# %%
# with data augmentation 
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   brightness_range=[0.4, 1.2],
                                   shear_range=0.2,
                                   zoom_range=0.3,
                                   validation_split=0.2)

train_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                    target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                    classes=None, 
                                                    class_mode='categorical',
                                                    batch_size=BATCH_SIZE, 
                                                    shuffle=True, 
                                                    subset='training')

validation_generator = train_datagen.flow_from_directory(TRAIN_DIR, 
                                                         target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                         classes=None, 
                                                         class_mode='categorical',
                                                         batch_size=BATCH_SIZE, 
                                                         shuffle=True, 
                                                         subset='validation')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(TEST_DIR, 
                                                  target_size=(INPUT_HEIGHT, INPUT_WIDTH),
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=False, 
                                                  class_mode='categorical')
# Out:
# Found 17943 images belonging to 10 classes.
# Found 4481 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.

# %%
# calculate the steps for training and validation
TRAIN_STEPS = train_generator.samples // BATCH_SIZE
VALIDATION_STEPS = validation_generator.samples // BATCH_SIZE

# %% [markdown]
# ## Basic CNN Architeture

# %%
model = models.Sequential()

# filters, stride, input size, chanel 
model.add(layers.Conv2D(32, (5,5), padding='same', input_shape=(INPUT_HEIGHT, INPUT_WIDTH, 3)))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(32) * height * width 

model.add(layers.Conv2D(64, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(64) * height/2 * width/2 

model.add(layers.Conv2D(128, (5,5), padding='same'))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.MaxPooling2D((2,2))) #size: number of filters(128) * height/4 * width/4 

model.add(layers.Flatten())

model.add(layers.Dropout(0.4))

model.add(layers.Dense(256))

model.add(layers.BatchNormalization())

model.add(layers.Activation("relu"))

model.add(layers.Dense(10))

model.add(layers.BatchNormalization())

model.add(layers.Activation("softmax"))

# %%
# use categorical crossentropy since our data is multi-class classification
#loss_func = losses.CategoricalCrossentropy(from_logits=False, name="categorical_crossentropy")

# outperforms others in practice, RMSprop + Momentum
#opt_func = optimizers.Adam(lr=0.0001)

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

#model.compile(loss=loss_func, 
#              optimizer=opt_func, 
#              metrics=['accuracy'])

# %%
# check the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 64, 64, 32)        2432
# _________________________________________________________________
# batch_normalization (BatchNo (None, 64, 64, 32)        128
# _________________________________________________________________
# activation (Activation)      (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               2097408
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_3 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10)                40
# _________________________________________________________________
# activation_4 (Activation)    (None, 10)                0
# =================================================================
# Total params: 2,360,562
# Trainable params: 2,359,582
# Non-trainable params: 980
# _________________________________________________________________

# %%
# plot the model in picture format to visualize how layers are connected with according input/output size
plot_model(model, to_file="basic_cnn_model.png", show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### Callback functions
#
# Callback functions are provided by *Keras*, which will be executed during the training of the model and can be used for different purposes; In this project, I will use the following three callback APIS:
# - EarlyStopping: stop the training earlier if the specified metric stopped improving
# - ReduceLROnPlateau: adjust the learning rate when the specified metric stopped improving
# - ModelCheckpoint: save the model weights and model each training epoch

# %%
# define callback functions
# 1: early stopping 
# https://keras.io/api/callbacks/early_stopping/
early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

# 2: reduce the learning rate when a metric has stopped improving 
# https://keras.io/api/callbacks/reduce_lr_on_plateau/
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',  # monitored metric
    factor=0.2,   # new lr = factor * lr
    patience=2,   # number of epochs 
    min_lr=0.001,  # min lr
    verbose=1
)

# 3: save model or model weights
# https://keras.io/api/callbacks/model_checkpoint/
model_path = MODEL_DIR + '/distracted_driver_detection_base.h5'
model_cp = ModelCheckpoint(
    filepath=model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

callbacks = [early_stop, reduce_lr, model_cp]
#callbacks = []

# %%
history=model.fit(train_generator, 
                  steps_per_epoch = TRAIN_STEPS, 
                  epochs = EPOCHES,
                  verbose = 1,
                  validation_data = validation_generator,
                  validation_steps = VALIDATION_STEPS,
                  callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 1.9814 - accuracy: 0.2923
# Epoch 00001: val_loss improved from inf to 2.46538, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 171s 1s/step - loss: 1.9814 - accuracy: 0.2923 - val_loss: 2.4654 - val_accuracy: 0.1078
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4292 - accuracy: 0.5252
# Epoch 00002: val_loss improved from 2.46538 to 2.23707, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 172s 1s/step - loss: 1.4292 - accuracy: 0.5252 - val_loss: 2.2371 - val_accuracy: 0.2364
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 1.0959 - accuracy: 0.6798
# Epoch 00003: val_loss improved from 2.23707 to 1.84312, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 173s 1s/step - loss: 1.0959 - accuracy: 0.6798 - val_loss: 1.8431 - val_accuracy: 0.3315
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 0.8854 - accuracy: 0.7526
# Epoch 00004: val_loss improved from 1.84312 to 1.07589, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 174s 1s/step - loss: 0.8854 - accuracy: 0.7526 - val_loss: 1.0759 - val_accuracy: 0.6734
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 0.7179 - accuracy: 0.8121
# Epoch 00005: val_loss improved from 1.07589 to 0.74280, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 173s 1s/step - loss: 0.7179 - accuracy: 0.8121 - val_loss: 0.7428 - val_accuracy: 0.8040
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 0.6012 - accuracy: 0.8480
# Epoch 00006: val_loss improved from 0.74280 to 0.73963, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 172s 1s/step - loss: 0.6012 - accuracy: 0.8480 - val_loss: 0.7396 - val_accuracy: 0.7754
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 0.5274 - accuracy: 0.8682
# Epoch 00007: val_loss improved from 0.73963 to 0.55235, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 173s 1s/step - loss: 0.5274 - accuracy: 0.8682 - val_loss: 0.5524 - val_accuracy: 0.8489
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4664 - accuracy: 0.8820
# Epoch 00008: val_loss improved from 0.55235 to 0.48123, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_base.h5
# 140/140 [==============================] - 174s 1s/step - loss: 0.4664 - accuracy: 0.8820 - val_loss: 0.4812 - val_accuracy: 0.8574
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 0.4238 - accuracy: 0.8943
# Epoch 00009: val_loss did not improve from 0.48123
# 140/140 [==============================] - 171s 1s/step - loss: 0.4238 - accuracy: 0.8943 - val_loss: 0.6740 - val_accuracy: 0.7835
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.9084
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.001.
#
# Epoch 00010: val_loss did not improve from 0.48123
# 140/140 [==============================] - 173s 1s/step - loss: 0.3721 - accuracy: 0.9084 - val_loss: 0.5861 - val_accuracy: 0.8145
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.9152Restoring model weights from the end of the best epoch.
#
# Epoch 00011: val_loss did not improve from 0.48123
# 140/140 [==============================] - 172s 1s/step - loss: 0.3433 - accuracy: 0.9152 - val_loss: 0.4866 - val_accuracy: 0.8569
# Epoch 00011: early stopping

# %% [markdown]
# ## Transfer learning on Pre-Trained Model (VGG-19)
#
# VGG-19 architecture is being used for this experienment.

# %%
conv_base = VGG19(weights="imagenet", 
                  include_top = False, # exclude the top three fully connected layer
                  input_shape = (INPUT_HEIGHT, INPUT_WIDTH, 3), # configure the input shape, default is 224*224*3
                 )

# %%
conv_base.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
x = conv_base.output

x = layers.Flatten()(x)

x = layers.Dropout(0.4)(x)

x = layers.Dense(256, activation='relu')(x)

predictions = layers.Dense(10, activation='softmax')(x)

# %%
t_model= models.Model(inputs=conv_base.input, outputs=predictions)

# %%
for layer in conv_base.layers:
    layer.trainable = False

#for layer in t_model.layers[:10]:
#    layer.trainable = False

# %%
#t_model.compile(loss='categorical_crossentropy', 
#                #optimizer='adam', 
#                optimizer=optimizers.Adam(lr=0.0001),
#                metrics=['accuracy'])

t_model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
t_model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 20,551,498
# Trainable params: 527,114
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
plot_model(t_model, to_file="transfered_model_vgg19.png", show_shapes=True, show_layer_names=True)

# %%
t_model_path = MODEL_DIR + '/distracted_driver_detection_vgg19.h5'
model_cp = ModelCheckpoint(
    filepath=t_model_path,
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stop = EarlyStopping(
    monitor="val_loss",
    min_delta = 0,
    patience=3,
    mode='min',
    restore_best_weights = True,
    verbose=1
)

callbacks = [model_cp, early_stop]

# %%
# reset data generator
train_generator.reset()
validation_generator.reset()

t_history=t_model.fit(train_generator, 
                      steps_per_epoch = TRAIN_STEPS, 
                      epochs = EPOCHES,
                      verbose = 1,
                      validation_data = validation_generator,
                      validation_steps = VALIDATION_STEPS,
                      callbacks = callbacks)
# Out:
# Epoch 1/50
# 140/140 [==============================] - ETA: 0s - loss: 2.1470 - accuracy: 0.2193
# Epoch 00001: val_loss improved from inf to 1.89355, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 2.1470 - accuracy: 0.2193 - val_loss: 1.8936 - val_accuracy: 0.3219
# Epoch 2/50
# 140/140 [==============================] - ETA: 0s - loss: 1.9203 - accuracy: 0.3068
# Epoch 00002: val_loss improved from 1.89355 to 1.82810, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 296s 2s/step - loss: 1.9203 - accuracy: 0.3068 - val_loss: 1.8281 - val_accuracy: 0.3511
# Epoch 3/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8570 - accuracy: 0.3358
# Epoch 00003: val_loss improved from 1.82810 to 1.74081, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.8570 - accuracy: 0.3358 - val_loss: 1.7408 - val_accuracy: 0.3757
# Epoch 4/50
# 140/140 [==============================] - ETA: 0s - loss: 1.8136 - accuracy: 0.3486
# Epoch 00004: val_loss improved from 1.74081 to 1.64980, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.8136 - accuracy: 0.3486 - val_loss: 1.6498 - val_accuracy: 0.4217
# Epoch 5/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7715 - accuracy: 0.3721
# Epoch 00005: val_loss did not improve from 1.64980
# 140/140 [==============================] - 296s 2s/step - loss: 1.7715 - accuracy: 0.3721 - val_loss: 1.6545 - val_accuracy: 0.4087
# Epoch 6/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7530 - accuracy: 0.3771
# Epoch 00006: val_loss improved from 1.64980 to 1.62962, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.7530 - accuracy: 0.3771 - val_loss: 1.6296 - val_accuracy: 0.4223
# Epoch 7/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7459 - accuracy: 0.3795
# Epoch 00007: val_loss improved from 1.62962 to 1.58884, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.7459 - accuracy: 0.3795 - val_loss: 1.5888 - val_accuracy: 0.4391
# Epoch 8/50
# 140/140 [==============================] - ETA: 0s - loss: 1.7156 - accuracy: 0.3866
# Epoch 00008: val_loss improved from 1.58884 to 1.57533, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 295s 2s/step - loss: 1.7156 - accuracy: 0.3866 - val_loss: 1.5753 - val_accuracy: 0.4580
# Epoch 9/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6993 - accuracy: 0.3955
# Epoch 00009: val_loss improved from 1.57533 to 1.53794, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 296s 2s/step - loss: 1.6993 - accuracy: 0.3955 - val_loss: 1.5379 - val_accuracy: 0.4598
# Epoch 10/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6880 - accuracy: 0.4002
# Epoch 00010: val_loss did not improve from 1.53794
# 140/140 [==============================] - 297s 2s/step - loss: 1.6880 - accuracy: 0.4002 - val_loss: 1.5473 - val_accuracy: 0.4605
# Epoch 11/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6783 - accuracy: 0.4029
# Epoch 00011: val_loss improved from 1.53794 to 1.51427, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 1.6783 - accuracy: 0.4029 - val_loss: 1.5143 - val_accuracy: 0.4792
# Epoch 12/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6577 - accuracy: 0.4097
# Epoch 00012: val_loss did not improve from 1.51427
# 140/140 [==============================] - 295s 2s/step - loss: 1.6577 - accuracy: 0.4097 - val_loss: 1.5159 - val_accuracy: 0.4824
# Epoch 13/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6602 - accuracy: 0.4090
# Epoch 00013: val_loss improved from 1.51427 to 1.47854, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 295s 2s/step - loss: 1.6602 - accuracy: 0.4090 - val_loss: 1.4785 - val_accuracy: 0.5040
# Epoch 14/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6204 - accuracy: 0.4285
# Epoch 00014: val_loss improved from 1.47854 to 1.44682, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 299s 2s/step - loss: 1.6204 - accuracy: 0.4285 - val_loss: 1.4468 - val_accuracy: 0.4975
# Epoch 15/50
# 140/140 [==============================] - ETA: 0s - loss: 1.6244 - accuracy: 0.4230
# Epoch 00015: val_loss did not improve from 1.44682
# 140/140 [==============================] - 297s 2s/step - loss: 1.6244 - accuracy: 0.4230 - val_loss: 1.4492 - val_accuracy: 0.5045
# Epoch 16/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5965 - accuracy: 0.4274
# Epoch 00016: val_loss improved from 1.44682 to 1.43247, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 297s 2s/step - loss: 1.5965 - accuracy: 0.4274 - val_loss: 1.4325 - val_accuracy: 0.5105
# Epoch 17/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5978 - accuracy: 0.4355
# Epoch 00017: val_loss did not improve from 1.43247
# 140/140 [==============================] - 297s 2s/step - loss: 1.5978 - accuracy: 0.4355 - val_loss: 1.4468 - val_accuracy: 0.5098
# Epoch 18/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5723 - accuracy: 0.4468
# Epoch 00018: val_loss improved from 1.43247 to 1.41034, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 299s 2s/step - loss: 1.5723 - accuracy: 0.4468 - val_loss: 1.4103 - val_accuracy: 0.5138
# Epoch 19/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5657 - accuracy: 0.4429
# Epoch 00019: val_loss improved from 1.41034 to 1.40817, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 298s 2s/step - loss: 1.5657 - accuracy: 0.4429 - val_loss: 1.4082 - val_accuracy: 0.5051
# Epoch 20/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5622 - accuracy: 0.4441
# Epoch 00020: val_loss improved from 1.40817 to 1.40116, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 303s 2s/step - loss: 1.5622 - accuracy: 0.4441 - val_loss: 1.4012 - val_accuracy: 0.5263
# Epoch 21/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5405 - accuracy: 0.4555
# Epoch 00021: val_loss improved from 1.40116 to 1.39252, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 309s 2s/step - loss: 1.5405 - accuracy: 0.4555 - val_loss: 1.3925 - val_accuracy: 0.5100
# Epoch 22/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5403 - accuracy: 0.4552
# Epoch 00022: val_loss improved from 1.39252 to 1.35198, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 1.5403 - accuracy: 0.4552 - val_loss: 1.3520 - val_accuracy: 0.5426
# Epoch 23/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5211 - accuracy: 0.4582
# Epoch 00023: val_loss did not improve from 1.35198
# 140/140 [==============================] - 305s 2s/step - loss: 1.5211 - accuracy: 0.4582 - val_loss: 1.3706 - val_accuracy: 0.5277
# Epoch 24/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5080 - accuracy: 0.4647
# Epoch 00024: val_loss did not improve from 1.35198
# 140/140 [==============================] - 304s 2s/step - loss: 1.5080 - accuracy: 0.4647 - val_loss: 1.3828 - val_accuracy: 0.5129
# Epoch 25/50
# 140/140 [==============================] - ETA: 0s - loss: 1.5052 - accuracy: 0.4676
# Epoch 00025: val_loss improved from 1.35198 to 1.33733, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 301s 2s/step - loss: 1.5052 - accuracy: 0.4676 - val_loss: 1.3373 - val_accuracy: 0.5527
# Epoch 26/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4955 - accuracy: 0.4694
# Epoch 00026: val_loss improved from 1.33733 to 1.32279, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 309s 2s/step - loss: 1.4955 - accuracy: 0.4694 - val_loss: 1.3228 - val_accuracy: 0.5397
# Epoch 27/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4927 - accuracy: 0.4688
# Epoch 00027: val_loss improved from 1.32279 to 1.30521, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 306s 2s/step - loss: 1.4927 - accuracy: 0.4688 - val_loss: 1.3052 - val_accuracy: 0.5513
# Epoch 28/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4729 - accuracy: 0.4805
# Epoch 00028: val_loss did not improve from 1.30521
# 140/140 [==============================] - 304s 2s/step - loss: 1.4729 - accuracy: 0.4805 - val_loss: 1.3253 - val_accuracy: 0.5460
# Epoch 29/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4618 - accuracy: 0.4858
# Epoch 00029: val_loss did not improve from 1.30521
# 140/140 [==============================] - 305s 2s/step - loss: 1.4618 - accuracy: 0.4858 - val_loss: 1.3089 - val_accuracy: 0.5531
# Epoch 30/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4662 - accuracy: 0.4763
# Epoch 00030: val_loss improved from 1.30521 to 1.26827, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 301s 2s/step - loss: 1.4662 - accuracy: 0.4763 - val_loss: 1.2683 - val_accuracy: 0.5562
# Epoch 31/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4490 - accuracy: 0.4831
# Epoch 00031: val_loss did not improve from 1.26827
# 140/140 [==============================] - 301s 2s/step - loss: 1.4490 - accuracy: 0.4831 - val_loss: 1.2715 - val_accuracy: 0.5676
# Epoch 32/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4442 - accuracy: 0.4859
# Epoch 00032: val_loss improved from 1.26827 to 1.24756, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 301s 2s/step - loss: 1.4442 - accuracy: 0.4859 - val_loss: 1.2476 - val_accuracy: 0.5842
# Epoch 33/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4491 - accuracy: 0.4845
# Epoch 00033: val_loss improved from 1.24756 to 1.24023, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 305s 2s/step - loss: 1.4491 - accuracy: 0.4845 - val_loss: 1.2402 - val_accuracy: 0.5808
# Epoch 34/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4360 - accuracy: 0.4909
# Epoch 00034: val_loss improved from 1.24023 to 1.23241, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 303s 2s/step - loss: 1.4360 - accuracy: 0.4909 - val_loss: 1.2324 - val_accuracy: 0.5808
# Epoch 35/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4354 - accuracy: 0.4909
# Epoch 00035: val_loss did not improve from 1.23241
# 140/140 [==============================] - 305s 2s/step - loss: 1.4354 - accuracy: 0.4909 - val_loss: 1.2553 - val_accuracy: 0.5730
# Epoch 36/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4185 - accuracy: 0.5037
# Epoch 00036: val_loss improved from 1.23241 to 1.23239, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 303s 2s/step - loss: 1.4185 - accuracy: 0.5037 - val_loss: 1.2324 - val_accuracy: 0.5942
# Epoch 37/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4115 - accuracy: 0.4999
# Epoch 00037: val_loss improved from 1.23239 to 1.22479, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 308s 2s/step - loss: 1.4115 - accuracy: 0.4999 - val_loss: 1.2248 - val_accuracy: 0.5933
# Epoch 38/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4151 - accuracy: 0.5028
# Epoch 00038: val_loss improved from 1.22479 to 1.21043, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 316s 2s/step - loss: 1.4151 - accuracy: 0.5028 - val_loss: 1.2104 - val_accuracy: 0.5902
# Epoch 39/50
# 140/140 [==============================] - ETA: 0s - loss: 1.4013 - accuracy: 0.5076
# Epoch 00039: val_loss did not improve from 1.21043
# 140/140 [==============================] - 307s 2s/step - loss: 1.4013 - accuracy: 0.5076 - val_loss: 1.2193 - val_accuracy: 0.5940
# Epoch 40/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3990 - accuracy: 0.5064
# Epoch 00040: val_loss improved from 1.21043 to 1.20626, saving model to /Users/jacobliu/Documents/GitHub/CS598-deep-learning/TermProject/saved_models/distracted_driver_detection_vgg19.h5
# 140/140 [==============================] - 314s 2s/step - loss: 1.3990 - accuracy: 0.5064 - val_loss: 1.2063 - val_accuracy: 0.6042
# Epoch 41/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3934 - accuracy: 0.5085
# Epoch 00041: val_loss did not improve from 1.20626
# 140/140 [==============================] - 308s 2s/step - loss: 1.3934 - accuracy: 0.5085 - val_loss: 1.2068 - val_accuracy: 0.6027
# Epoch 42/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3801 - accuracy: 0.5165
# Epoch 00042: val_loss did not improve from 1.20626
# 140/140 [==============================] - 307s 2s/step - loss: 1.3801 - accuracy: 0.5165 - val_loss: 1.2154 - val_accuracy: 0.5801
# Epoch 43/50
# 140/140 [==============================] - ETA: 0s - loss: 1.3783 - accuracy: 0.5139
# Epoch 00043: val_loss did not improve from 1.20626
# Restoring model weights from the end of the best epoch.
# 140/140 [==============================] - 310s 2s/step - loss: 1.3783 - accuracy: 0.5139 - val_loss: 1.2075 - val_accuracy: 0.5929
# Epoch 00043: early stopping

# %% [markdown]
# ## Performance Evalution
#
# Performance will be evaluated on losses and accuracy for trainning and validation. The function below is a generic function that can be used to plot either one based on user input.

# %%
def show_metric(history, metric):
    '''
    history: return value of the .fit, which includes all the history while training the model
    metric: which metric to plot
    '''
    train_metrics = history.history[metric]
    validation_metrics = history.history['val_' + metric]
    
    # make it start from 1
    train_epochs = range(1, len(train_metrics) + 1)
    
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
    plt.plot(train_epochs, train_metrics)
    plt.plot(train_epochs, validation_metrics)
    
    plt.title('Training and Validation '+ metric)
    
    plt.xlabel("Number of Epochs")
    plt.ylabel(metric)
    
    plt.legend(["Training " + metric, "Validation " + metric])
    plt.show()

    
def plot_confusion_matrix(data, labels):
    """Plot confusion matrix using heatmap.
 
    Args:
        data (list of list): List of lists with confusion matrix data.
        labels (list): Labels which will be plotted across x and y axis.
        output_filename (str): Path to output file.
 
    """
    sns.set(color_codes=True)
    plt.figure(1, figsize=(8, 6))
 
    plt.title("Confusion Matrix")
     
    ax = sns.heatmap(data, annot=True, cmap="YlGnBu", cbar_kws={'label': 'Scale'})
 
    ax.set_xticklabels(labels)
    ax.set_yticklabels(labels)
 
    ax.set(ylabel="True Label", xlabel="Predicted Label")
     
    plt.show()

# %% [markdown]
# #### Basic CNN Architecture

# %%
show_metric(history, "loss")
show_metric(history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 921us/step - loss: 0.7616 - accuracy: 0.7400
# Loss: 0.7615519165992737
# Accuracy: 0.7400000095367432

# %%
test_generator.reset()
preds = model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c7       0.70      0.70      0.70        10
#           c4       0.67      1.00      0.80        10
#           c9       0.75      0.90      0.82        10
#           c0       0.90      0.90      0.90        10
#           c2       0.73      0.80      0.76        10
#           c1       0.83      1.00      0.91        10
#           c8       0.67      0.40      0.50        10
#           c5       0.80      0.80      0.80        10
#           c6       0.70      0.70      0.70        10
#           c3       0.50      0.20      0.29        10
#
#     accuracy                           0.74       100
#    macro avg       0.72      0.74      0.72       100
# weighted avg       0.72      0.74      0.72       100

# %% [markdown]
# ### Model with transfer learning on pre-trained model

# %%
show_metric(t_history, "loss")
show_metric(t_history, "accuracy")

# %%
test_generator.reset()
loss, accuracy = t_model.evaluate(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
print("Loss:",loss)
print("Accuracy:", accuracy)
# Out:
# 1/1 [==============================] - 0s 994us/step - loss: 1.5460 - accuracy: 0.4800
# Loss: 1.5459868907928467
# Accuracy: 0.47999998927116394

# %%
test_generator.reset()
preds = t_model.predict(test_generator, steps=test_generator.samples//BATCH_SIZE+1)
preds = np.argmax(preds, axis=1)

cr = classification_report(test_generator.classes, preds, target_names=classes)
print('Classification Report')
print(cr)

cm = confusion_matrix(test_generator.classes, preds)
plot_confusion_matrix(cm, classes)
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#           c7       0.75      0.60      0.67        10
#           c4       0.44      0.40      0.42        10
#           c9       0.43      0.60      0.50        10
#           c0       0.67      0.40      0.50        10
#           c2       0.67      0.40      0.50        10
#           c1       1.00      0.70      0.82        10
#           c8       0.33      0.30      0.32        10
#           c5       0.50      0.60      0.55        10
#           c6       0.45      0.50      0.48        10
#           c3       0.17      0.30      0.21        10
#
#     accuracy                           0.48       100
#    macro avg       0.54      0.48      0.50       100
# weighted avg       0.54      0.48      0.50       100

# %% [markdown]
# ## Model verification

# %%
def show_test_images(model):
    plt.subplots(figsize=(20, 6))
 
    for i in range(0, 10):              
        plt.subplot(2, 5, i+1)

        choosen_cls=random.choice(os.listdir(TEST_DIR))
        
        path = os.path.join(TEST_DIR, choosen_cls)
        
        choosen_file=random.choice(os.listdir(path))
        
        f_path = os.path.join(path, choosen_file)
        
        image = load_img(path=f_path, target_size=(INPUT_HEIGHT, INPUT_WIDTH))
        input_arr = img_to_array(image)
        input_arr = np.array([input_arr])  # Convert single image to a batch.
        predictions = model.predict(input_arr)
        
        predicted_class = 'c'+str(np.argmax(predictions))
        
        title_str = "Predicted: "+class_dict[predicted_class]
        
        image = mpimg.imread(f_path)
        
        plt.imshow(image)
        plt.title(title_str)
        plt.axis('off')

    plt.show()

# %%
# Load the model
base_model = models.load_model(model_path, compile=True)

show_test_images(base_model)

# %%
vgg19_model = models.load_model(t_model_path, compile = True)

show_test_images(vgg19_model)

# %% [markdown]
# ## Reference
#
# Image classification from scratch: https://keras.io/examples/vision/image_classification_from_scratch/
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# Building powerful image classification models using very little data: https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
#
# Tutorial on using Keras flow_from_directory and generators: https://vijayabhaskar96.medium.com/tutorial-image-classification-with-keras-flow-from-directory-and-generators-95f75ebe5720
#
# Losses: https://keras.io/api/losses/
#
# How to use Callbacks in Keras to Visualize, Monitor and Improve your Deep Learning Model: https://medium.com/iitg-ai/how-to-use-callbacks-in-keras-to-visualize-monitor-and-improve-your-deep-learning-model-c9ca37901b28
#
# Image data preprocessing: https://keras.io/api/preprocessing/image/#image_dataset_from_directory-function
#
# Using Keras Image Data Generator with Transfer Learning: https://becominghuman.ai/using-keras-imagedatagenerator-with-transfer-learning-c4787d430060
#
# A Practical Introduction to Keras Callbacks in TensorFlow 2: https://towardsdatascience.com/a-practical-introduction-to-keras-callbacks-in-tensorflow-2-705d0c584966
#
# 4 Pre-Trained CNN Models to Use for Computer Vision with Transfer Learning: https://towardsdatascience.com/4-pre-trained-cnn-models-to-use-for-computer-vision-with-transfer-learning-885cb1b2dfc
#
# Keras Applications: https://keras.io/api/applications/
#
#  A simple example: Confusion Matrix with Keras flow_from_directory.py: https://gist.github.com/RyanAkilos/3808c17f79e77c4117de35aa68447045#file-a-simple-example-confusion-matrix-with-keras-flow_from_directory-py
